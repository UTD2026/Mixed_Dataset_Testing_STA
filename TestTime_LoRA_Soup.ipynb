# %% [markdown]
# <a href="https://colab.research.google.com/github/UTD2026/Mixed_Dataset_Testing_STA/blob/main/TestTime_LoRA_Soup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test-Time LoRA Soup: does merging diverse test-slice adapters beat single-adapter TTL?
#
# The open seam: LoRA souping/merging (AdapterSoup, LoRA-Soups, TIES/DARE) all assume
# **labeled domains/skills**. TLM's setting has none — one unlabeled test stream. Nobody has
# asked whether souping K adapters trained on diverse slices of the *single test set* beats a
# single TLM adapter. This is **weight-space averaging**, not the output-vote that already
# failed (a vote drowns the minority adapter; averaging blends parameters, no per-item oracle).
#
# Arms (souping K=3 adapters, linear weight-average):
# - `soup_seed`   : K adapters on **all data, different seeds** -> pure souping regularization
# - `soup_kmeans` : K adapters on **k-means embedding clusters** -> diversity souping (the hypothesis)
# - `soup_random` : K adapters on **random N/K splits**          -> partition control
# Baselines (cached from beat_tlm): `tlm` (single, high-ppl), `fulldata` (single, all data).
#
# Win = a soup arm beats BOTH `tlm` and `fulldata` on all 3 datasets. `soup_seed` isolates the
# regularization gain; `soup_kmeans - soup_seed` isolates the diversity gain (your `diversity_gain`
# finding cashing in). Cheap on the Blackwell card; reuses cached tlm/fulldata/features/base.

# %%
# ---- repo / runtime knobs ----
REPO_URL = "https://github.com/UTD2026/rishabh-tlm.git"
WORK = "/content/v2_dynamic_ce"                       # change if not on Colab
LOCAL_REPO_ZIP = "/content/rishabh-tlm-ab-routing-2026-07-02.zip"  # clone fallback
GITHUB_TOKEN_ENV = "GITHUB_TOKEN"                     # optional, for private clone
MODEL = "Qwen/Qwen3.5-0.8B"
DATASETS = ["logiqa", "medicine", "geography"]        # geography = honest negative case
N_BY_DATASET = {"logiqa": 1000, "medicine": 1000, "geography": 225}
print({"work": WORK, "model": MODEL, "datasets": DATASETS})
# Out:
# {'work': '/content/v2_dynamic_ce', 'model': 'Qwen/Qwen3.5-0.8B', 'datasets': ['logiqa', 'medicine', 'geography']}

# %% [markdown]
# ## Environment setup
#
# Written for a CUDA GPU box (Colab/H200/Ada). Skip the install cell if your image already has these packages.

# %%
import os, sys, subprocess, json, textwrap, shutil, pathlib, time
from pathlib import Path

Path(WORK).mkdir(parents=True, exist_ok=True)
os.chdir(WORK)
print("cwd:", os.getcwd())
# Out:
# cwd: /content/v2_dynamic_ce

# %%
# Fresh Colab runtime install / compatibility setup.
# Qwen3.5 needs newer Transformers support. Generation is patched to use Transformers,
# because Colab/vLLM CUDA wheels can mismatch (e.g. libcudart.so.13 missing).
# Runtime > Restart runtime after this cell if pip asks or if imports still show stale versions.
import os, sys, subprocess, shutil

INSTALL_DEPS = True
USE_QWEN35_COMPAT_INSTALL = True  # keep True for MODEL="Qwen/Qwen3.5-0.8B"
INSTALL_VLLM = False  # keep False on Colab unless you have a known-compatible vLLM/CUDA wheel

if INSTALL_DEPS:
    def pip_install(*args):
        cmd = [sys.executable, "-m", "pip", "install", "-U", *args]
        print("RUN:", " ".join(cmd))
        subprocess.check_call(cmd)

    pip_install("pip")
    pip_install("peft", "accelerate", "scipy", "sympy", "ninja", "pandas", "matplotlib", "torchvision", "pillow", "huggingface_hub")

    if USE_QWEN35_COMPAT_INSTALL and "Qwen3.5" in MODEL:
        # HF model card recommends latest Transformers for Qwen3.5.
        pip_install("transformers[serving] @ git+https://github.com/huggingface/transformers.git@main")
    else:
        pip_install("transformers")

    if INSTALL_VLLM:
        # Optional only. The notebook patches ab_generate.py to use Transformers by default.
        # Use this only if your runtime has a vLLM wheel matching its CUDA/PyTorch stack.
        try:
            cmd = [sys.executable, "-m", "pip", "install", "-U", "vllm", "--extra-index-url", "https://wheels.vllm.ai/nightly"]
            print("RUN:", " ".join(cmd))
            subprocess.check_call(cmd)
        except Exception as e:
            print("Nightly vLLM install failed, falling back to normal vLLM:", repr(e))
            pip_install("vllm")

    # Qwen3.5 GDN Triton JIT expects ninja on PATH in this codebase's README.
    ninja = shutil.which("ninja")
    if ninja:
        print("ninja:", ninja)
    else:
        print("WARNING: ninja still not found on PATH")

import torch, transformers
print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("gpu:", torch.cuda.get_device_name(0))
print("transformers:", transformers.__version__)
if INSTALL_VLLM:
    try:
        import vllm
        print("vllm:", getattr(vllm, "__version__", "unknown"))
    except Exception as e:
        print("vllm import warning:", repr(e))
else:
    print("vllm skipped; ab_generate.py will use Transformers fallback")
# Out:
# RUN: /usr/bin/python3 -m pip install -U pip
# RUN: /usr/bin/python3 -m pip install -U peft accelerate scipy sympy ninja pandas matplotlib torchvision pillow huggingface_hub
# RUN: /usr/bin/python3 -m pip install -U transformers[serving] @ git+https://github.com/huggingface/transformers.git@main
# ninja: /usr/local/bin/ninja
# torch: 2.12.1+cu130
# cuda available: True
# gpu: NVIDIA RTX PRO 6000 Blackwell Server Edition
# transformers: 5.14.0.dev0
# vllm skipped; ab_generate.py will use Transformers fallback

# %% [markdown]
# ### Fix CUDA / optional-dependency mismatches (torchaudio, torchvision, torchao)
#
# Current Colab images carry several optional extensions that are *installed but version- or
# CUDA-mismatched*, and the git-main `transformers` / `peft` treat "present but incompatible" as
# a hard error instead of "absent, skip it":
#
# - `torchaudio` is built for CUDA 12.8 against a CUDA-13 PyTorch. `transformers` imports it while
#   loading **text** model modules (`peft` -> `BloomPreTrainedModel` -> `loss_utils` -> `loss_rnnt`),
#   so its CUDA check crashes the whole pipeline.
# - `torchao` ships as 0.10.0, but `peft`'s LoRA dispatcher requires > 0.16.0 and *raises* from
#   `is_torchao_available()` during `get_peft_model(...)` even though this LoRA config uses plain
#   `Linear` layers and never needs torchao.
# - `torchvision` can mismatch CUDA the same way as torchaudio.
#
# None of these are used by this text-only pipeline (no audio, no vision, no quantization), so we
# remove them. Once each is absent, the corresponding `is_*_available()` guard returns `False` and
# the code skips it cleanly. The cell then forces the exact import + LoRA path the subprocesses use,
# so any remaining mismatch surfaces here instead of deep inside a stage.

# %%
import sys, subprocess

def _pip(*args):
    print("RUN: pip", *args)
    subprocess.check_call([sys.executable, "-m", "pip", *args])

# Remove optional extensions that are installed-but-incompatible (unused by this pipeline).
for pkg in ["torchaudio", "torchvision", "torchao"]:
    try:
        _pip("uninstall", "-y", pkg)
    except Exception as e:
        print(f"(uninstall {pkg} skipped: {e!r})")

# Drop any half-loaded modules so the verification imports are clean.
for m in list(sys.modules):
    if m.startswith(("torchaudio", "torchvision", "torchao", "transformers", "peft")):
        del sys.modules[m]

import torch
print("torch:", torch.__version__, "| cuda build:", torch.version.cuda, "| cuda avail:", torch.cuda.is_available())

# Force the exact eager chain the subprocesses trigger: text-model import + a LoRA injection.
from transformers import AutoModelForCausalLM, AutoTokenizer, BloomPreTrainedModel  # noqa: F401
from peft import LoraConfig, TaskType, get_peft_model  # noqa: F401
import torch.nn as nn
_probe = nn.Linear(8, 8)
class _Tiny(nn.Module):
    def __init__(self):
        super().__init__()
        self.proj = nn.Linear(8, 8)
    def forward(self, x):
        return self.proj(x)
_ = get_peft_model(_Tiny(), LoraConfig(target_modules=["proj"], r=2))  # exercises the LoRA dispatcher
print("transformers + peft + LoRA dispatch OK (no torchaudio/torchao crash)")
# Out:
# RUN: pip uninstall -y torchaudio
# RUN: pip uninstall -y torchvision
# RUN: pip uninstall -y torchao
# torch: 2.12.1+cu130 | cuda build: 13.0 | cuda avail: True
# transformers + peft + LoRA dispatch OK (no torchaudio/torchao crash)

# %%
# Clone / update repo, with token + zip fallback
import os, subprocess, shutil, zipfile, glob
from pathlib import Path

repo_dir = Path(WORK) / "rishabh-tlm"


def _run_capture(cmd, cwd=None):
    """Run a shell command and return CompletedProcess while preserving stdout/stderr."""
    return subprocess.run(
        [str(x) for x in cmd],
        cwd=cwd,
        text=True,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
    )


def _clone_url_with_optional_token(url: str) -> str:
    token = os.environ.get(GITHUB_TOKEN_ENV, "").strip()
    if token and url.startswith("https://github.com/"):
        # Do not print this URL; it contains a secret.
        return url.replace("https://", f"https://{token}@", 1)
    return url


def _unzip_repo(zip_path: Path, dest: Path):
    zip_path = Path(zip_path).expanduser().resolve()
    if not zip_path.exists():
        raise FileNotFoundError(f"Repo zip does not exist: {zip_path}")

    print(f"Using repo zip fallback: {zip_path}")
    tmp = dest.parent / "_repo_zip_extract_tmp"
    if tmp.exists():
        shutil.rmtree(tmp)
    tmp.mkdir(parents=True, exist_ok=True)

    with zipfile.ZipFile(zip_path, "r") as zf:
        zf.extractall(tmp)

    # Common cases: zip contains a single top-level folder, or contains repo files directly.
    candidates = [p for p in tmp.iterdir() if p.is_dir()]
    selected = None
    for cand in candidates:
        if (cand / "cuda_ttl" / "ab_routing").exists() or (cand / ".git").exists():
            selected = cand
            break
    if selected is None:
        if (tmp / "cuda_ttl" / "ab_routing").exists():
            selected = tmp
        elif len(candidates) == 1:
            selected = candidates[0]
        else:
            raise RuntimeError(
                "Could not identify repo root inside zip. "
                f"Top-level entries: {[p.name for p in tmp.iterdir()][:20]}"
            )

    if dest.exists():
        shutil.rmtree(dest)
    if selected == tmp:
        shutil.copytree(tmp, dest, dirs_exist_ok=True)
        shutil.rmtree(tmp, ignore_errors=True)
    else:
        shutil.move(str(selected), str(dest))
        shutil.rmtree(tmp, ignore_errors=True)

    if not (dest / "cuda_ttl" / "ab_routing").exists():
        raise RuntimeError(f"Unzipped repo does not contain cuda_ttl/ab_routing: {dest}")


def _find_repo_zip():
    """Find an already-present repo zip in the locations Colab commonly uses."""
    explicit = Path(LOCAL_REPO_ZIP).expanduser()
    search_roots = [
        explicit.parent,
        Path(WORK),
        Path.cwd(),
        Path("/content"),
        Path("/mnt/data"),  # works in ChatGPT sandbox, harmless in Colab if absent
    ]

    candidates = []
    if explicit.exists():
        candidates.append(explicit)
    for root in search_roots:
        try:
            if root.exists():
                candidates.extend(Path(x) for x in glob.glob(str(root / "rishabh-tlm*.zip")))
        except Exception:
            pass

    # de-dupe while preserving order
    out = []
    seen = set()
    for c in candidates:
        try:
            resolved = c.resolve()
        except Exception:
            continue
        if c.exists() and resolved not in seen:
            out.append(c)
            seen.add(resolved)
    return out[0] if out else None


def _upload_repo_zip_colab():
    """Upload a zip in Colab and return the actual path it was written to.

    Colab saves uploads into the current working directory, not necessarily /content.
    The previous notebook assumed /content/<name>, which caused FileNotFoundError.
    This version verifies the path and falls back to writing uploaded bytes manually.
    """
    from google.colab import files

    print("No local repo zip found. Upload rishabh-tlm-ab-routing-2026-07-02.zip now.")
    uploaded = files.upload()
    zip_names = [name for name in uploaded if name.lower().endswith(".zip")]
    if not zip_names:
        raise RuntimeError("No .zip file uploaded.")

    name = zip_names[0]
    candidates = [
        Path.cwd() / name,
        Path(WORK) / name,
        Path("/content") / name,
        Path(name),
    ]
    for candidate in candidates:
        if candidate.exists():
            print(f"Uploaded zip found at: {candidate.resolve()}")
            return candidate.resolve()

    # Defensive fallback: Colab returned bytes, so write them somewhere we control.
    fallback = Path(WORK) / name
    fallback.parent.mkdir(parents=True, exist_ok=True)
    fallback.write_bytes(uploaded[name])
    print(f"Uploaded zip bytes written to: {fallback.resolve()}")
    return fallback.resolve()


if repo_dir.exists():
    print("repo already exists:", repo_dir)
    # keep this non-destructive; uncomment if you explicitly want latest remote
    # subprocess.check_call(["git", "-C", str(repo_dir), "pull"])
else:
    clone_url = _clone_url_with_optional_token(REPO_URL)
    print("Cloning repo...")
    cp = _run_capture(["git", "clone", clone_url, str(repo_dir)])
    if cp.returncode != 0:
        print("git clone failed.")
        if cp.stdout.strip():
            print("--- git stdout ---")
            print(cp.stdout[-4000:])
        if cp.stderr.strip():
            print("--- git stderr ---")
            # Redact token if present.
            safe_stderr = cp.stderr
            token = os.environ.get(GITHUB_TOKEN_ENV, "").strip()
            if token:
                safe_stderr = safe_stderr.replace(token, "<GITHUB_TOKEN>")
            print(safe_stderr[-4000:])

        zip_path = _find_repo_zip()
        if zip_path is None:
            try:
                zip_path = _upload_repo_zip_colab()
            except Exception as upload_e:
                raise RuntimeError(
                    "Could not clone the repo and no repo zip fallback was available.\n\n"
                    "Most likely causes:\n"
                    "1) The GitHub repo is private and Colab has no auth. Set os.environ['GITHUB_TOKEN'] first.\n"
                    "2) The URL/branch is wrong or unavailable.\n"
                    "3) Colab/network blocked GitHub.\n\n"
                    f"Original git error:\n{cp.stderr[-2000:]}"
                ) from upload_e

        _unzip_repo(Path(zip_path), repo_dir)

os.chdir(repo_dir)
print("repo:", repo_dir)
try:
    head = subprocess.check_output(["git", "rev-parse", "--short", "HEAD"], text=True, stderr=subprocess.DEVNULL).strip()
    print("git head:", head)
except Exception:
    print("git head unavailable: repo loaded from zip or non-git folder")

print("ab_routing files:")
for p in sorted((repo_dir / "cuda_ttl" / "ab_routing").glob("ab_*.py")):
    print(" -", p.relative_to(repo_dir))
# Out:
# repo already exists: /content/v2_dynamic_ce/rishabh-tlm
# repo: /content/v2_dynamic_ce/rishabh-tlm
# git head unavailable: repo loaded from zip or non-git folder
# ab_routing files:
#  - cuda_ttl/ab_routing/ab_build_pool.py
#  - cuda_ttl/ab_routing/ab_generate.py
#  - cuda_ttl/ab_routing/ab_route_eval.py
#  - cuda_ttl/ab_routing/ab_train_ttl.py
#  - cuda_ttl/ab_routing/ab_train_ttl_anchored.py

# %%
# Runtime patch: make model loading more robust for Qwen3.5 and add clear preflight checks.
# This is non-destructive to the repo ZIP; it only edits the working copy inside WORK.
from pathlib import Path
import subprocess, sys, os

if not Path("cuda_ttl/ab_routing/ab_build_pool.py").exists():
    raise FileNotFoundError("Run the repo setup cell first; cuda_ttl/ab_routing/ab_build_pool.py not found.")

# 1) ab_build_pool.py originally hard-coded AutoModelForCausalLM.
# For Qwen3.5, use the checkpoint-declared architecture when Transformers knows it;
# otherwise fall back to AutoModelForCausalLM.
p = Path("cuda_ttl/ab_routing/ab_build_pool.py")
s = p.read_text()
s = s.replace(
    '    from transformers import AutoModelForCausalLM, AutoTokenizer\n'
    '    from peft import LoraConfig, TaskType, get_peft_model\n'
    '    tokenizer = AutoTokenizer.from_pretrained(args.model)\n'
    '    model = AutoModelForCausalLM.from_pretrained(args.model, torch_dtype=torch.bfloat16,\n'
    '                                                 device_map="cuda")\n',
    '    import transformers\n'
    '    from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer\n'
    '    from peft import LoraConfig, TaskType, get_peft_model\n'
    '    tokenizer = AutoTokenizer.from_pretrained(args.model, trust_remote_code=True)\n'
    '    cfg = AutoConfig.from_pretrained(args.model, trust_remote_code=True)\n'
    '    arch = (getattr(cfg, "architectures", None) or [""])[0]\n'
    '    model_cls = getattr(transformers, arch, None) or AutoModelForCausalLM\n'
    '    print(f"loading with {model_cls.__name__}")\n'
    '    model = model_cls.from_pretrained(args.model, torch_dtype=torch.bfloat16,\n'
    '                                      device_map="cuda", trust_remote_code=True)\n'
)
p.write_text(s)

# 2) Add trust_remote_code to train loader too, same idea.
p = Path("cuda_ttl/ab_routing/ab_train_ttl.py")
s = p.read_text()
s = s.replace('    tokenizer = AutoTokenizer.from_pretrained(args.model)\n', '    tokenizer = AutoTokenizer.from_pretrained(args.model, trust_remote_code=True)\n')
s = s.replace('    cfg = AutoConfig.from_pretrained(args.model)\n', '    cfg = AutoConfig.from_pretrained(args.model, trust_remote_code=True)\n')
s = s.replace('    model = model_cls.from_pretrained(args.model, torch_dtype=torch.bfloat16,\n                                      device_map="cuda")\n',
              '    model = model_cls.from_pretrained(args.model, torch_dtype=torch.bfloat16,\n                                      device_map="cuda", trust_remote_code=True)\n')
p.write_text(s)

# 3) Hard preflight before burning time.
import torch, transformers
from transformers import AutoConfig, AutoTokenizer
print("MODEL =", MODEL)
print("torch =", torch.__version__)
print("transformers =", transformers.__version__)
print("cuda =", torch.cuda.is_available())
if not torch.cuda.is_available():
    raise RuntimeError("CUDA is not available. In Colab: Runtime -> Change runtime type -> GPU.")
print("gpu =", torch.cuda.get_device_name(0))
try:
    tok = AutoTokenizer.from_pretrained(MODEL, trust_remote_code=True)
    cfg = AutoConfig.from_pretrained(MODEL, trust_remote_code=True)
    print("model_type =", getattr(cfg, "model_type", None))
    print("architectures =", getattr(cfg, "architectures", None))
    print("tokenizer ok; chat_template =", bool(getattr(tok, "chat_template", None)))
except Exception as e:
    raise RuntimeError(
        "Model/tokenizer preflight failed. If MODEL is Qwen/Qwen3.5-0.8B, rerun the install cell, "
        "restart runtime if needed, or set MODEL='Qwen/Qwen2.5-0.5B-Instruct' for a text-only smoke test."
    ) from e

print("patched scripts ok")
for file in ["ab_build_pool.py", "ab_train_ttl.py"]:
    subprocess.check_call([sys.executable, "-m", "py_compile", str(Path("cuda_ttl/ab_routing") / file)])
    print("py_compile ok:", file)
# Out:
# MODEL = Qwen/Qwen3.5-0.8B
# torch = 2.12.1+cu130
# transformers = 5.14.0.dev0
# cuda = True
# gpu = NVIDIA RTX PRO 6000 Blackwell Server Edition
# model_type = qwen3_5
# architectures = ['Qwen3_5ForConditionalGeneration']
# tokenizer ok; chat_template = True
# patched scripts ok
# py_compile ok: ab_build_pool.py
# py_compile ok: ab_train_ttl.py

# %%
# Data paths expected by cuda_ttl/ab_routing/run_ab.sh, but we call scripts directly.
DATA_FILES = {
    "logiqa": "data/AdaptEval/logiqa_random_5k.json",
    "medicine": "data/AdaptEval/medicine_mcqa_random_5k.json",
    "geography": "data/AdaptEval/geography_mmlu.json",
    "gsm8k": "data/AdaptEval/gsm8k_random_5k.json",
}

missing = [p for ds, p in DATA_FILES.items() if ds in DATASETS and not Path(p).exists()]
if missing:
    raise FileNotFoundError(
        "Missing dataset files: " + ", ".join(missing) +
        "\nThe uploaded repo snapshot included these under data/AdaptEval/. If your clone does not, copy them there before running."
    )

for ds in DATASETS:
    print(ds, "->", DATA_FILES[ds], "exists", Path(DATA_FILES[ds]).exists())
# Out:
# logiqa -> data/AdaptEval/logiqa_random_5k.json exists True
# medicine -> data/AdaptEval/medicine_mcqa_random_5k.json exists True
# geography -> data/AdaptEval/geography_mmlu.json exists True

# %%
# ---- resolve paths (cwd is the repo root after the clone cell) ----
from pathlib import Path
SCRIPTS = Path("cuda_ttl/ab_routing").resolve()
REPO_DIR = Path.cwd()
ARTIFACT_ROOT = Path(WORK) / "saves_dynamic_v2ce"   # reuse prior pools/base preds if present
ANCHOR_ROOT = Path(WORK) / "saves_anchor"           # this experiment's outputs
ANCHOR_ROOT.mkdir(parents=True, exist_ok=True)
assert SCRIPTS.exists(), "run the clone cell first"
print("repo:", REPO_DIR, "| scripts:", SCRIPTS)
# Out:
# repo: /content/v2_dynamic_ce/rishabh-tlm | scripts: /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing

# %% [markdown]
# ## Write the anchored trainer
#
# Writes `ab_train_ttl_anchored.py` (vanilla objective at `--anchor-lambda 0` plus the anchor flags) and the HF `ab_generate.py`. Both are py-compiled here so a syntax problem surfaces before any GPU time.

# %%
# ---- write the anchored trainer and the HF generation script into the repo ----
import subprocess, sys
from pathlib import Path

trainer_src = "#!/usr/bin/env python\n\"\"\"\nStage 2: TTL LoRA training on the admission-selected pool \u2014 CUDA port of\nmlx_ttl/train_ttl_mlx.py in its --selection-file mode (CE gate bypassed; train ONLY on\nthe selected idxs, weighted). Same recipe: chat-templated (user, assistant=output)\npairs, loss on completion tokens only, LoRA q_proj+v_proj r8 alpha16 dropout0 on all\nlayers, AdamW lr 5e-5, cosine schedule with 10% warmup, 1 epoch, batch 1, seed 42.\n\nSaves the peft adapter AND a merged full model (merge_and_unload) so vLLM generation\ncannot silently no-op the adapter (the vLLM-0.24 LoRA module-naming gotcha).\n\"\"\"\n\nimport argparse\nimport json\nimport math\nimport os\nimport random\nimport time\n\nimport torch\n\n\ndef build_user(rec):\n    if \"instruction\" in rec:\n        instruction = (rec.get(\"instruction\") or \"\").strip()\n        extra = (rec.get(\"input\") or \"\").strip()\n        return instruction + ((\"\\n\" + extra) if extra else \"\")\n    return (rec.get(\"question\") or \"\").strip()\n\n\ndef chat_ids(tokenizer, msgs, add_generation_prompt):\n    # template to STRING then encode (BatchEncoding gotcha \u2014 see ab_build_pool.py)\n    try:\n        text = tokenizer.apply_chat_template(\n            msgs, tokenize=False, add_generation_prompt=add_generation_prompt,\n            enable_thinking=False)\n    except TypeError:\n        text = tokenizer.apply_chat_template(\n            msgs, tokenize=False, add_generation_prompt=add_generation_prompt)\n    return tokenizer.encode(text, add_special_tokens=False)\n\n\ndef main():\n    ap = argparse.ArgumentParser(description=\"TTL LoRA on a selected pool (CUDA)\")\n    ap.add_argument(\"--model\", default=\"Qwen/Qwen3.5-0.8B\")\n    ap.add_argument(\"--data\", required=True)\n    ap.add_argument(\"--selection-file\", required=True)\n    ap.add_argument(\"--output-dir\", required=True)\n    ap.add_argument(\"--merged-dir\", default=None, help=\"default <output-dir>/merged\")\n    ap.add_argument(\"--max-samples\", type=int, default=1000)\n    ap.add_argument(\"--max-seq-length\", type=int, default=2048)\n    ap.add_argument(\"--epochs\", type=float, default=1.0)\n    ap.add_argument(\"--learning-rate\", type=float, default=5e-5)\n    ap.add_argument(\"--warmup-ratio\", type=float, default=0.1)\n    ap.add_argument(\"--lora-rank\", type=int, default=8)\n    ap.add_argument(\"--lora-alpha\", type=int, default=16)\n    ap.add_argument(\"--lora-keys\", default=\"q_proj,v_proj\")\n    ap.add_argument(\"--seed\", type=int, default=42)\n    # --- base-anchor (confidence-weighted KL to frozen base) ---\n    ap.add_argument(\"--anchor-lambda\", type=float, default=0.0,\n                    help=\"strength of the base-anchor term; 0.0 == vanilla TLM\")\n    ap.add_argument(\"--anchor-weight\", default=\"confidence\",\n                    choices=[\"confidence\", \"threshold\", \"uniform\"],\n                    help=\"per-token weight on the anchor: confidence=base gold-prob^gamma, \"\n                         \"threshold=1 where base gold-CE<=tau, uniform=1 everywhere\")\n    ap.add_argument(\"--anchor-direction\", default=\"fwd\", choices=[\"fwd\", \"rev\"],\n                    help=\"fwd=KL(base||adapted) (pull adapted toward base); rev=KL(adapted||base)\")\n    ap.add_argument(\"--anchor-tau\", type=float, default=0.3,\n                    help=\"base gold-token CE threshold for --anchor-weight threshold\")\n    ap.add_argument(\"--anchor-gamma\", type=float, default=1.0,\n                    help=\"sharpening exponent for --anchor-weight confidence\")\n    args = ap.parse_args()\n    merged_dir = args.merged_dir or os.path.join(args.output_dir, \"merged\")\n    os.makedirs(args.output_dir, exist_ok=True)\n\n    torch.manual_seed(args.seed)\n    sel = json.load(open(args.selection_file))\n    weights = {int(e[\"idx\"]): float(e[\"weight\"]) for e in sel[\"selected\"]}\n\n    import transformers\n    from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer, get_cosine_schedule_with_warmup\n    from peft import LoraConfig, TaskType, get_peft_model\n    tokenizer = AutoTokenizer.from_pretrained(args.model)\n    # Load via the checkpoint's own architecture class (Qwen3_5ForConditionalGeneration),\n    # NOT AutoModelForCausalLM: the latter returns the text submodel, whose merged\n    # save_pretrained writes a Qwen3_5TextConfig that vLLM refuses to load.\n    cfg = AutoConfig.from_pretrained(args.model)\n    arch = (getattr(cfg, \"architectures\", None) or [\"\"])[0]\n    model_cls = getattr(transformers, arch, None) or AutoModelForCausalLM\n    print(f\"loading with {model_cls.__name__}\")\n    model = model_cls.from_pretrained(args.model, torch_dtype=torch.bfloat16,\n                                      device_map=\"cuda\")\n    model = get_peft_model(model, LoraConfig(\n        task_type=TaskType.CAUSAL_LM, r=args.lora_rank, lora_alpha=args.lora_alpha,\n        lora_dropout=0.0, bias=\"none\",\n        target_modules=[k.strip() for k in args.lora_keys.split(\",\")]))\n    model.print_trainable_parameters()\n    device = next(model.parameters()).device\n\n    records = json.load(open(args.data, encoding=\"utf-8\"))[: args.max_samples]\n    samples = []  # (full_ids, prompt_len, idx)\n    for idx, rec in enumerate(records):\n        if idx not in weights:\n            continue\n        user = build_user(rec)\n        output = str(rec.get(\"output\") if \"output\" in rec else rec.get(\"answers\", \"\") or \"\")\n        if not user:\n            continue\n        prompt_ids = chat_ids(tokenizer, [{\"role\": \"user\", \"content\": user}], True)\n        full_ids = chat_ids(tokenizer, [{\"role\": \"user\", \"content\": user},\n                                        {\"role\": \"assistant\", \"content\": output}], False)\n        full_ids = full_ids[: args.max_seq_length]\n        if len(full_ids) <= len(prompt_ids):\n            continue\n        samples.append((full_ids, len(prompt_ids), idx))\n    print(f\"training on {len(samples)} selected samples\")\n\n    steps_per_epoch = len(samples)\n    total_steps = int(steps_per_epoch * args.epochs)\n    warmup_steps = max(1, int(total_steps * args.warmup_ratio))\n    opt = torch.optim.AdamW((p for p in model.parameters() if p.requires_grad),\n                            lr=args.learning_rate)\n    sched = get_cosine_schedule_with_warmup(opt, warmup_steps, total_steps)\n\n    model.train()\n    step, running, t0 = 0, 0.0, time.perf_counter()\n    for epoch in range(math.ceil(args.epochs)):\n        order = list(range(len(samples)))\n        random.Random(args.seed + epoch).shuffle(order)\n        for j in order:\n            if step >= total_steps:\n                break\n            full_ids, plen, idx = samples[j]\n            x = torch.tensor([full_ids], device=device)\n            logits = model(input_ids=x).logits.float()\n            tgt = x[:, 1:]\n            lp = torch.log_softmax(logits[:, :-1, :], dim=-1)\n            ce = -lp.gather(-1, tgt.unsqueeze(-1)).squeeze(-1)[0]\n            task_loss = ce[plen - 1:].mean() * weights[idx]\n\n            # --- base-anchor: confidence-weighted KL to the frozen base -------------\n            # (base = same model with the LoRA adapter disabled; no second model needed)\n            if args.anchor_lambda > 0.0:\n                with torch.no_grad():\n                    with model.disable_adapter():\n                        base_logits = model(input_ids=x).logits.float()\n                la = lp[:, plen - 1:, :]                                   # adapted logp (grad)\n                lb = torch.log_softmax(base_logits[:, :-1, :], dim=-1)[:, plen - 1:, :].detach()\n                if args.anchor_direction == \"fwd\":                        # KL(base||adapted)\n                    kl = (lb.exp() * (lb - la)).sum(-1)[0]\n                else:                                                     # KL(adapted||base)\n                    pa = la.exp()\n                    kl = (pa * (la - lb)).sum(-1)[0]\n                tgt_comp = tgt[:, plen - 1:][0]\n                base_gold_lp = lb[0].gather(-1, tgt_comp.view(-1, 1)).squeeze(-1)  # base logp on gold\n                if args.anchor_weight == \"confidence\":\n                    w = base_gold_lp.exp().clamp(1e-6, 1.0).pow(args.anchor_gamma)\n                elif args.anchor_weight == \"threshold\":\n                    w = ((-base_gold_lp) <= args.anchor_tau).float()\n                else:\n                    w = torch.ones_like(kl)\n                w = w.detach()\n                anchor_loss = (w * kl).sum() / (w.sum() + 1e-8)\n                loss = task_loss + args.anchor_lambda * anchor_loss\n            else:\n                anchor_loss = None\n                loss = task_loss\n            # -----------------------------------------------------------------------\n            opt.zero_grad(set_to_none=True)\n            loss.backward()\n            opt.step()\n            sched.step()\n            running += loss.item()\n            step += 1\n            if step % 20 == 0:\n                extra = \"\" if anchor_loss is None else f\" | anchor {anchor_loss.item():.4f}\"\n                print(f\"step {step}/{total_steps} | loss {running/20:.4f}{extra} \"\n                      f\"| lr {sched.get_last_lr()[0]:.2e} | {step/(time.perf_counter()-t0):.2f} it/s\",\n                      flush=True)\n                running = 0.0\n        if step >= total_steps:\n            break\n\n    model.save_pretrained(args.output_dir)\n    print(f\"adapter -> {args.output_dir}\")\n    merged = model.merge_and_unload()\n    merged.save_pretrained(merged_dir)\n    tokenizer.save_pretrained(merged_dir)\n    # The composite Qwen3.5 arch makes vLLM look for (video) preprocessor configs that\n    # save_pretrained doesn't write \u2014 copy any missing non-weight files from the source\n    # checkpoint so the merged dir loads exactly like the hub model.\n    import shutil\n    from huggingface_hub import snapshot_download\n    src = args.model if os.path.isdir(args.model) else snapshot_download(\n        args.model, allow_patterns=[\"*.json\", \"*.txt\", \"*.jinja\"])\n    for name in os.listdir(src):\n        if \"safetensors\" in name or not os.path.isfile(os.path.join(src, name)):\n            continue\n        dst = os.path.join(merged_dir, name)\n        if not os.path.exists(dst):\n            shutil.copy(os.path.join(src, name), dst)\n            print(f\"  copied {name} from source checkpoint\")\n    print(f\"merged model -> {merged_dir}\")\n\n\nif __name__ == \"__main__\":\n    main()\n"
gen_src = "#!/usr/bin/env python\n\"\"\"\nStage 3: greedy predictions for an AdaptEval bench.\n\nPatched notebook version: uses Hugging Face Transformers instead of vLLM so Colab\nis not blocked by vLLM/CUDA wheel mismatches such as missing libcudart.so.13.\nOutput rows {idx, question, label, predict} match the original script.\n\"\"\"\n\nimport argparse\nimport json\nimport os\nimport time\n\n\ndef build_user(rec):\n    if \"instruction\" in rec:\n        instruction = (rec.get(\"instruction\") or \"\").strip()\n        extra = (rec.get(\"input\") or \"\").strip()\n        return instruction + ((\"\\n\" + extra) if extra else \"\")\n    return (rec.get(\"question\") or \"\").strip()\n\n\ndef gold_label(rec):\n    if rec.get(\"answer\") not in (None, \"\"):\n        return str(rec[\"answer\"]).strip()\n    val = rec.get(\"output\") if \"output\" in rec else rec.get(\"answers\")\n    return str(val or \"\").strip()\n\n\ndef _load_model_and_tokenizer(model_name_or_path):\n    import torch\n    import transformers\n    from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer\n\n    tokenizer = AutoTokenizer.from_pretrained(model_name_or_path, trust_remote_code=True)\n    if tokenizer.pad_token_id is None:\n        tokenizer.pad_token = tokenizer.eos_token\n    tokenizer.padding_side = \"left\"\n\n    cfg = AutoConfig.from_pretrained(model_name_or_path, trust_remote_code=True)\n    arch = (getattr(cfg, \"architectures\", None) or [\"\"])[0]\n    model_cls = getattr(transformers, arch, None) or AutoModelForCausalLM\n    print(f\"loading with {model_cls.__name__}\")\n\n    model = model_cls.from_pretrained(\n        model_name_or_path,\n        torch_dtype=torch.bfloat16 if torch.cuda.is_available() else torch.float32,\n        device_map=\"auto\" if torch.cuda.is_available() else None,\n        trust_remote_code=True,\n    )\n    model.eval()\n    return model, tokenizer\n\n\ndef main():\n    ap = argparse.ArgumentParser(description=\"Transformers greedy predictions for AdaptEval\")\n    ap.add_argument(\"--model\", required=True)\n    ap.add_argument(\"--data\", required=True)\n    ap.add_argument(\"--output\", required=True)\n    ap.add_argument(\"--max-samples\", type=int, default=1000)\n    ap.add_argument(\"--max-new-tokens\", type=int, default=1024)\n    ap.add_argument(\"--gpu-mem\", type=float, default=0.85, help=\"kept for CLI compatibility; ignored\")\n    ap.add_argument(\"--max-model-len\", type=int, default=4096)\n    ap.add_argument(\"--batch-size\", type=int, default=8)\n    args = ap.parse_args()\n\n    records = json.load(open(args.data, encoding=\"utf-8\"))[: args.max_samples]\n\n    model, tokenizer = _load_model_and_tokenizer(args.model)\n\n    def chat(user):\n        msgs = [{\"role\": \"user\", \"content\": user}]\n        try:\n            return tokenizer.apply_chat_template(\n                msgs, tokenize=False, add_generation_prompt=True, enable_thinking=False\n            )\n        except TypeError:\n            return tokenizer.apply_chat_template(\n                msgs, tokenize=False, add_generation_prompt=True\n            )\n\n    built = []\n    for idx, rec in enumerate(records):\n        user = build_user(rec)\n        if not user:\n            continue\n        built.append((idx, user, gold_label(rec), chat(user)))\n\n    import torch\n    t0 = time.perf_counter()\n    predictions = []\n\n    for start in range(0, len(built), args.batch_size):\n        chunk = built[start : start + args.batch_size]\n        prompts = [b[3] for b in chunk]\n        enc = tokenizer(\n            prompts,\n            return_tensors=\"pt\",\n            padding=True,\n            truncation=True,\n            max_length=args.max_model_len,\n        )\n        enc = {k: v.to(model.device) for k, v in enc.items()}\n        input_width = enc[\"input_ids\"].shape[1]\n\n        with torch.inference_mode():\n            out_ids = model.generate(\n                **enc,\n                do_sample=False,\n                max_new_tokens=args.max_new_tokens,\n                pad_token_id=tokenizer.pad_token_id,\n                eos_token_id=tokenizer.eos_token_id,\n            )\n\n        gen_ids = out_ids[:, input_width:]\n        texts = tokenizer.batch_decode(gen_ids, skip_special_tokens=True)\n        predictions.extend(texts)\n\n        done = min(start + len(chunk), len(built))\n        if done % 100 == 0 or done == len(built):\n            print(f\"generated {done}/{len(built)}\", flush=True)\n\n    print(f\"{len(built)} prompts in {time.perf_counter()-t0:.1f}s\")\n\n    os.makedirs(os.path.dirname(args.output) or \".\", exist_ok=True)\n    with open(args.output, \"w\", encoding=\"utf-8\") as f:\n        for (idx, user, label, _p), pred in zip(built, predictions):\n            f.write(json.dumps({\"idx\": idx, \"question\": user, \"label\": label,\n                                \"predict\": pred}, ensure_ascii=False) + \"\\n\")\n    print(f\"-> {args.output}\")\n\n\nif __name__ == \"__main__\":\n    main()\n"

tp = SCRIPTS / 'ab_train_ttl_anchored.py'
gp = SCRIPTS / 'ab_generate.py'   # ensure HF (not vLLM) generation
tp.write_text(trainer_src, encoding='utf-8')
gp.write_text(gen_src, encoding='utf-8')
for p in (tp, gp):
    subprocess.check_call([sys.executable, '-m', 'py_compile', str(p)])
print('wrote + py_compile ok:', tp.name, gp.name)
# Out:
# wrote + py_compile ok: ab_train_ttl_anchored.py ab_generate.py

# %% [markdown]
# ## Config (reuses beat_tlm cache)

# %%
from pathlib import Path
import json, subprocess, sys, time, shutil, os
import numpy as np
sys.path.insert(0, str(SCRIPTS)); import grading

ROOT = Path(WORK) / "saves_beat_tlm"      # reuse cached tlm/fulldata/features/base
LOG = ROOT / "logs"; LOG.mkdir(parents=True, exist_ok=True)
QV = "q_proj,v_proj"
K        = 3           # adapters per soup
MAXNEW, GEN_BATCH, EPOCHS, LR = 12, 64, 1.0, 5e-5
SOUP_ARMS = {"soup_seed": "seed", "soup_kmeans": "kmeans", "soup_random": "random"}

def sh(cmd, log):
    print("RUN:", " ".join(map(str, cmd)))
    t0 = time.perf_counter(); Path(log).parent.mkdir(parents=True, exist_ok=True)
    with open(log, "w") as f:
        p = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
        for ln in p.stdout: print(ln, end=""); f.write(ln)
        rc = p.wait()
    print(f"rc={rc} {(time.perf_counter()-t0)/60:.1f} min")
    if rc: raise RuntimeError(f"failed: {cmd}")

def _build_user(rec):
    if "instruction" in rec:
        ins = (rec.get("instruction") or "").strip(); ex = (rec.get("input") or "").strip()
        return ins + (("\n" + ex) if ex else "")
    return (rec.get("question") or "").strip()

def load_base():
    import torch, transformers
    from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer
    tok = AutoTokenizer.from_pretrained(MODEL, trust_remote_code=True)
    if tok.pad_token_id is None: tok.pad_token = tok.eos_token
    cfg = AutoConfig.from_pretrained(MODEL, trust_remote_code=True)
    arch = (getattr(cfg, "architectures", None) or [""])[0]
    cls = getattr(transformers, arch, None) or AutoModelForCausalLM
    m = cls.from_pretrained(MODEL, torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="cuda")
    return m, tok
print("soup arms:", list(SOUP_ARMS), "| K =", K)
# Out:
# soup arms: ['soup_seed', 'soup_kmeans', 'soup_random'] | K = 3

# %% [markdown]
# ## 1) Build K slices per arm (seed / kmeans / random) + selection files

# %%
# ---- ensure features + base preds + tlm/fulldata baselines exist (self-contained) ----
QV = "q_proj,v_proj"
def _write_sel(path, idxs):
    Path(path).parent.mkdir(parents=True, exist_ok=True)
    json.dump({"selected":[{"idx":int(i),"weight":1.0} for i in idxs]}, open(path,"w"))

for ds in DATASETS:
    pool = ROOT/ds/"pool"; fp = pool/"features.jsonl"
    if not fp.exists():
        sh([sys.executable, str(SCRIPTS/"ab_build_pool.py"), "--model", MODEL, "--data", DATA_FILES[ds],
            "--dataset", ds, "--max-samples", str(N_BY_DATASET[ds]), "--out-dir", str(pool)],
           LOG/f"{ds}_pool.log")
    idx = [json.loads(l)["idx"] for l in open(fp) if l.strip()]
    q   = {json.loads(l)["idx"]: json.loads(l)["q_ce"] for l in open(fp) if l.strip()}
    cap = len(json.load(open(pool/"selection.json"))["selected"])
    hi  = sorted(idx, key=lambda i: q[i], reverse=True)[:cap]      # TLM high-perplexity pool
    _write_sel(ROOT/ds/"tlm"/"selection.json", hi)
    _write_sel(ROOT/ds/"fulldata"/"selection.json", idx)
    bp = ROOT/ds/"preds_base.jsonl"
    if not bp.exists():
        sh([sys.executable, str(SCRIPTS/"ab_generate.py"), "--model", MODEL, "--data", DATA_FILES[ds],
            "--max-samples", str(N_BY_DATASET[ds]), "--output", str(bp), "--max-new-tokens", str(MAXNEW)],
           LOG/f"{ds}_base.log")
    for arm in ["tlm", "fulldata"]:
        ap = ROOT/ds/arm/"preds_adapted.jsonl"; merged = ROOT/ds/arm/"adapter"/"merged"
        if ap.exists(): continue
        sh([sys.executable, str(SCRIPTS/"ab_train_ttl_anchored.py"), "--model", MODEL, "--data", DATA_FILES[ds],
            "--selection-file", str(ROOT/ds/arm/"selection.json"), "--max-samples", str(N_BY_DATASET[ds]),
            "--output-dir", str(ROOT/ds/arm/"adapter"), "--lora-rank","8","--lora-alpha","16","--lora-keys",QV,
            "--epochs",str(EPOCHS),"--learning-rate",str(LR),"--anchor-lambda","0.0","--seed","0"],
           LOG/f"{ds}_{arm}_train.log")
        sh([sys.executable, str(SCRIPTS/"ab_generate.py"), "--model", str(merged), "--data", DATA_FILES[ds],
            "--max-samples", str(N_BY_DATASET[ds]), "--output", str(ap), "--max-new-tokens", str(MAXNEW)],
           LOG/f"{ds}_{arm}_gen.log")
    print(ds, "features + base + tlm + fulldata ready")
# Out:
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_build_pool.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/logiqa_random_5k.json --dataset logiqa --max-samples 1000 --out-dir /content/v2_dynamic_ce/saves_beat_tlm/logiqa/pool
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  74%|███████▍  | 349/473 [00:00<00:00, 3478.93it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4089.90it/s]
# 1000 usable items from 1000 records
# capacity=100 init=10 warmup=100 grad_budget=400
#   proxy 100/1000 | 7.6/s
#   proxy 200/1000 | 7.7/s
#   proxy 300/1000 | 7.7/s
#   proxy 400/1000 | 7.7/s
#   proxy 500/1000 | 7.7/s
#   proxy 600/1000 | 7.7/s
#   proxy 700/1000 | 7.7/s
#   proxy 800/1000 | 7.7/s
#   proxy 900/1000 | 7.7/s
#   proxy 1000/1000 | 7.7/s
#   warmup grads 50/100 | 4.2/s
#   warmup grads 100/100 | 4.3/s
#   stream 100/1000 selected=100 grads=100 | 37.2/s
#   stream 200/1000 selected=100 grads=136 | 18.2/s
#   stream 300/1000 selected=100 grads=164 | 16.9/s
#   stream 800/1000 selected=100 grads=328 | 14.2/s
# {
#   "dataset": "logiqa",
#   "model": "Qwen/Qwen3.5-0.8B",
#   "n": 1000,
#   "capacity": 100,
#   "init_count": 10,
#   "warmup": 100,
#   "gradient_budget": 400,
#   "gradients_computed": 400,
#   "shortlist": 300,
#   "final_pool": 100,
#   "route_counts": {
#     "base": 730,
#     "adapted": 270
#   }
# }
# rc=0 3.9 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/logiqa_random_5k.json --max-samples 1000 --output /content/v2_dynamic_ce/saves_beat_tlm/logiqa/preds_base.jsonl --max-new-tokens 12
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  86%|████████▋ | 408/473 [00:00<00:00, 4074.60it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4339.95it/s]
# generated 200/1000
# generated 400/1000
# generated 600/1000
# generated 800/1000
# generated 1000/1000
# 1000 prompts in 11.1s
# -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/preds_base.jsonl
# rc=0 0.3 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/logiqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/logiqa/tlm/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/logiqa/tlm/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  54%|█████▎    | 254/473 [00:00<00:00, 2531.64it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3456.33it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 100 selected samples
# step 20/100 | loss 0.5217 | lr 4.85e-05 | 3.68 it/s
# step 40/100 | loss 0.5757 | lr 3.75e-05 | 3.89 it/s
# step 60/100 | loss 0.5243 | lr 2.07e-05 | 3.94 it/s
# step 80/100 | loss 0.5298 | lr 5.85e-06 | 3.97 it/s
# step 100/100 | loss 0.5644 | lr 0.00e+00 | 3.99 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/tlm/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 95.18it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/tlm/adapter/merged
# rc=0 0.5 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/logiqa/tlm/adapter/merged --data data/AdaptEval/logiqa_random_5k.json --max-samples 1000 --output /content/v2_dynamic_ce/saves_beat_tlm/logiqa/tlm/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  59%|█████▉    | 279/473 [00:00<00:00, 2778.25it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3630.85it/s]
# generated 200/1000
# generated 400/1000
# generated 600/1000
# generated 800/1000
# generated 1000/1000
# 1000 prompts in 10.9s
# -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/tlm/preds_adapted.jsonl
# rc=0 0.3 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/logiqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/logiqa/fulldata/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/logiqa/fulldata/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  73%|███████▎  | 346/473 [00:00<00:00, 3458.42it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4087.00it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 1000 selected samples
# step 20/1000 | loss 0.5165 | lr 1.00e-05 | 3.76 it/s
# step 40/1000 | loss 0.6718 | lr 2.00e-05 | 3.96 it/s
# step 60/1000 | loss 0.6111 | lr 3.00e-05 | 4.01 it/s
# step 80/1000 | loss 0.4388 | lr 4.00e-05 | 4.04 it/s
# step 100/1000 | loss 0.4936 | lr 5.00e-05 | 4.05 it/s
# step 120/1000 | loss 0.3999 | lr 4.99e-05 | 4.05 it/s
# step 140/1000 | loss 0.4529 | lr 4.98e-05 | 4.07 it/s
# step 160/1000 | loss 0.4430 | lr 4.95e-05 | 4.08 it/s
# step 180/1000 | loss 0.4589 | lr 4.90e-05 | 4.09 it/s
# step 200/1000 | loss 0.4716 | lr 4.85e-05 | 4.10 it/s
# step 220/1000 | loss 0.4358 | lr 4.78e-05 | 4.09 it/s
# step 240/1000 | loss 0.4758 | lr 4.71e-05 | 4.09 it/s
# step 260/1000 | loss 0.3993 | lr 4.62e-05 | 4.10 it/s
# step 280/1000 | loss 0.4367 | lr 4.52e-05 | 4.11 it/s
# step 300/1000 | loss 0.3726 | lr 4.42e-05 | 4.10 it/s
# step 320/1000 | loss 0.4111 | lr 4.30e-05 | 4.10 it/s
# step 340/1000 | loss 0.4154 | lr 4.17e-05 | 4.11 it/s
# step 360/1000 | loss 0.4320 | lr 4.04e-05 | 4.12 it/s
# step 380/1000 | loss 0.4036 | lr 3.90e-05 | 4.12 it/s
# step 400/1000 | loss 0.4418 | lr 3.75e-05 | 4.12 it/s
# step 420/1000 | loss 0.4605 | lr 3.60e-05 | 4.12 it/s
# step 440/1000 | loss 0.3764 | lr 3.44e-05 | 4.12 it/s
# step 460/1000 | loss 0.3704 | lr 3.27e-05 | 4.12 it/s
# step 480/1000 | loss 0.4072 | lr 3.10e-05 | 4.12 it/s
# step 500/1000 | loss 0.4107 | lr 2.93e-05 | 4.12 it/s
# step 520/1000 | loss 0.4117 | lr 2.76e-05 | 4.12 it/s
# step 540/1000 | loss 0.4053 | lr 2.59e-05 | 4.13 it/s
# step 560/1000 | loss 0.4447 | lr 2.41e-05 | 4.12 it/s
# step 580/1000 | loss 0.4415 | lr 2.24e-05 | 4.12 it/s
# step 600/1000 | loss 0.4760 | lr 2.07e-05 | 4.12 it/s
# step 620/1000 | loss 0.4422 | lr 1.90e-05 | 4.12 it/s
# step 640/1000 | loss 0.3947 | lr 1.73e-05 | 4.12 it/s
# step 660/1000 | loss 0.4715 | lr 1.56e-05 | 4.12 it/s
# step 680/1000 | loss 0.4352 | lr 1.40e-05 | 4.12 it/s
# step 700/1000 | loss 0.4323 | lr 1.25e-05 | 4.12 it/s
# step 720/1000 | loss 0.4155 | lr 1.10e-05 | 4.12 it/s
# step 740/1000 | loss 0.5467 | lr 9.61e-06 | 4.12 it/s
# step 760/1000 | loss 0.4225 | lr 8.27e-06 | 4.12 it/s
# step 780/1000 | loss 0.3533 | lr 7.02e-06 | 4.12 it/s
# step 800/1000 | loss 0.3834 | lr 5.85e-06 | 4.12 it/s
# step 820/1000 | loss 0.4572 | lr 4.77e-06 | 4.12 it/s
# step 840/1000 | loss 0.4208 | lr 3.80e-06 | 4.12 it/s
# step 860/1000 | loss 0.3261 | lr 2.93e-06 | 4.12 it/s
# step 880/1000 | loss 0.4336 | lr 2.16e-06 | 4.12 it/s
# step 900/1000 | loss 0.3514 | lr 1.51e-06 | 4.12 it/s
# step 920/1000 | loss 0.3831 | lr 9.68e-07 | 4.12 it/s
# step 940/1000 | loss 0.4033 | lr 5.46e-07 | 4.12 it/s
# step 960/1000 | loss 0.3658 | lr 2.43e-07 | 4.12 it/s
# step 980/1000 | loss 0.3534 | lr 6.09e-08 | 4.12 it/s
# step 1000/1000 | loss 0.4371 | lr 0.00e+00 | 4.12 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/fulldata/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 20537.94it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/fulldata/adapter/merged
# rc=0 4.2 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/logiqa/fulldata/adapter/merged --data data/AdaptEval/logiqa_random_5k.json --max-samples 1000 --output /content/v2_dynamic_ce/saves_beat_tlm/logiqa/fulldata/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  66%|██████▌   | 311/473 [00:00<00:00, 3106.00it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3888.45it/s]
# generated 200/1000
# generated 400/1000
# generated 600/1000
# generated 800/1000
# generated 1000/1000
# 1000 prompts in 10.9s
# -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/fulldata/preds_adapted.jsonl
# rc=0 0.3 min
# logiqa features + base + tlm + fulldata ready
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_build_pool.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/medicine_mcqa_random_5k.json --dataset medicine --max-samples 1000 --out-dir /content/v2_dynamic_ce/saves_beat_tlm/medicine/pool
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  74%|███████▍  | 349/473 [00:00<00:00, 3488.27it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4044.87it/s]
# 1000 usable items from 1000 records
# capacity=100 init=10 warmup=100 grad_budget=400
#   proxy 100/1000 | 7.5/s
#   proxy 200/1000 | 7.6/s
#   proxy 300/1000 | 7.6/s
#   proxy 400/1000 | 7.6/s
#   proxy 500/1000 | 7.6/s
#   proxy 600/1000 | 7.6/s
#   proxy 700/1000 | 7.6/s
#   proxy 800/1000 | 7.6/s
#   proxy 900/1000 | 7.6/s
#   proxy 1000/1000 | 7.6/s
#   warmup grads 50/100 | 4.1/s
#   warmup grads 100/100 | 4.1/s
#   stream 100/1000 selected=100 grads=100 | 36.8/s
#   stream 600/1000 selected=100 grads=277 | 13.5/s
#   stream 700/1000 selected=100 grads=310 | 13.4/s
#   stream 800/1000 selected=100 grads=337 | 13.6/s
# {
#   "dataset": "medicine",
#   "model": "Qwen/Qwen3.5-0.8B",
#   "n": 1000,
#   "capacity": 100,
#   "init_count": 10,
#   "warmup": 100,
#   "gradient_budget": 400,
#   "gradients_computed": 400,
#   "shortlist": 300,
#   "final_pool": 100,
#   "route_counts": {
#     "base": 745,
#     "adapted": 255
#   }
# }
# rc=0 3.9 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/medicine_mcqa_random_5k.json --max-samples 1000 --output /content/v2_dynamic_ce/saves_beat_tlm/medicine/preds_base.jsonl --max-new-tokens 12
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  55%|█████▍    | 258/473 [00:00<00:00, 2577.18it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3565.43it/s]
# generated 200/1000
# generated 400/1000
# generated 600/1000
# generated 800/1000
# generated 1000/1000
# 1000 prompts in 28.1s
# -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/preds_base.jsonl
# rc=0 0.6 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/medicine_mcqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/medicine/tlm/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/medicine/tlm/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  56%|█████▌    | 264/473 [00:00<00:00, 2625.04it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3567.54it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 100 selected samples
# step 20/100 | loss 0.7531 | lr 4.85e-05 | 3.75 it/s
# step 40/100 | loss 0.6240 | lr 3.75e-05 | 3.93 it/s
# step 60/100 | loss 0.4160 | lr 2.07e-05 | 4.00 it/s
# step 80/100 | loss 0.3970 | lr 5.85e-06 | 4.04 it/s
# step 100/100 | loss 0.4396 | lr 0.00e+00 | 4.06 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/tlm/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 83330.54it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/tlm/adapter/merged
# rc=0 0.5 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/medicine/tlm/adapter/merged --data data/AdaptEval/medicine_mcqa_random_5k.json --max-samples 1000 --output /content/v2_dynamic_ce/saves_beat_tlm/medicine/tlm/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  62%|██████▏   | 292/473 [00:00<00:00, 2907.82it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3822.86it/s]
# generated 200/1000
# generated 400/1000
# generated 600/1000
# generated 800/1000
# generated 1000/1000
# 1000 prompts in 12.4s
# -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/tlm/preds_adapted.jsonl
# rc=0 0.3 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/medicine_mcqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/medicine/fulldata/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/medicine/fulldata/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  53%|█████▎    | 251/473 [00:00<00:00, 2488.43it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3446.97it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 1000 selected samples
# step 20/1000 | loss 0.7867 | lr 1.00e-05 | 3.77 it/s
# step 40/1000 | loss 0.9097 | lr 2.00e-05 | 3.90 it/s
# step 60/1000 | loss 0.8785 | lr 3.00e-05 | 3.95 it/s
# step 80/1000 | loss 0.5442 | lr 4.00e-05 | 3.98 it/s
# step 100/1000 | loss 0.4471 | lr 5.00e-05 | 3.99 it/s
# step 120/1000 | loss 0.4536 | lr 4.99e-05 | 3.96 it/s
# step 140/1000 | loss 0.3476 | lr 4.98e-05 | 3.98 it/s
# step 160/1000 | loss 0.3899 | lr 4.95e-05 | 4.00 it/s
# step 180/1000 | loss 0.5313 | lr 4.90e-05 | 4.00 it/s
# step 200/1000 | loss 0.4359 | lr 4.85e-05 | 4.01 it/s
# step 220/1000 | loss 0.3896 | lr 4.78e-05 | 4.00 it/s
# step 240/1000 | loss 0.4096 | lr 4.71e-05 | 4.00 it/s
# step 260/1000 | loss 0.4216 | lr 4.62e-05 | 4.01 it/s
# step 280/1000 | loss 0.4276 | lr 4.52e-05 | 4.01 it/s
# step 300/1000 | loss 0.3987 | lr 4.42e-05 | 4.01 it/s
# step 320/1000 | loss 0.4671 | lr 4.30e-05 | 4.00 it/s
# step 340/1000 | loss 0.4219 | lr 4.17e-05 | 4.01 it/s
# step 360/1000 | loss 0.4319 | lr 4.04e-05 | 4.01 it/s
# step 380/1000 | loss 0.5697 | lr 3.90e-05 | 4.01 it/s
# step 400/1000 | loss 0.3866 | lr 3.75e-05 | 4.02 it/s
# step 420/1000 | loss 0.4711 | lr 3.60e-05 | 4.01 it/s
# step 440/1000 | loss 0.4607 | lr 3.44e-05 | 4.01 it/s
# step 460/1000 | loss 0.4338 | lr 3.27e-05 | 4.02 it/s
# step 480/1000 | loss 0.4683 | lr 3.10e-05 | 4.02 it/s
# step 500/1000 | loss 0.4084 | lr 2.93e-05 | 4.02 it/s
# step 520/1000 | loss 0.4401 | lr 2.76e-05 | 4.02 it/s
# step 540/1000 | loss 0.4056 | lr 2.59e-05 | 4.02 it/s
# step 560/1000 | loss 0.4414 | lr 2.41e-05 | 4.03 it/s
# step 580/1000 | loss 0.3726 | lr 2.24e-05 | 4.04 it/s
# step 600/1000 | loss 0.4520 | lr 2.07e-05 | 4.05 it/s
# step 620/1000 | loss 0.3757 | lr 1.90e-05 | 4.06 it/s
# step 640/1000 | loss 0.3955 | lr 1.73e-05 | 4.07 it/s
# step 660/1000 | loss 0.3875 | lr 1.56e-05 | 4.07 it/s
# step 680/1000 | loss 0.4270 | lr 1.40e-05 | 4.08 it/s
# step 700/1000 | loss 0.4314 | lr 1.25e-05 | 4.09 it/s
# step 720/1000 | loss 0.3957 | lr 1.10e-05 | 4.10 it/s
# step 740/1000 | loss 0.4438 | lr 9.61e-06 | 4.10 it/s
# step 760/1000 | loss 0.4165 | lr 8.27e-06 | 4.11 it/s
# step 780/1000 | loss 0.4157 | lr 7.02e-06 | 4.12 it/s
# step 800/1000 | loss 0.3928 | lr 5.85e-06 | 4.12 it/s
# step 820/1000 | loss 0.4312 | lr 4.77e-06 | 4.13 it/s
# step 840/1000 | loss 0.3892 | lr 3.80e-06 | 4.13 it/s
# step 860/1000 | loss 0.3835 | lr 2.93e-06 | 4.14 it/s
# step 880/1000 | loss 0.4255 | lr 2.16e-06 | 4.14 it/s
# step 900/1000 | loss 0.3642 | lr 1.51e-06 | 4.15 it/s
# step 920/1000 | loss 0.3740 | lr 9.68e-07 | 4.15 it/s
# step 940/1000 | loss 0.3482 | lr 5.46e-07 | 4.15 it/s
# step 960/1000 | loss 0.4532 | lr 2.43e-07 | 4.16 it/s
# step 980/1000 | loss 0.4512 | lr 6.09e-08 | 4.16 it/s
# step 1000/1000 | loss 0.3946 | lr 0.00e+00 | 4.16 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/fulldata/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 80832.41it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/fulldata/adapter/merged
# rc=0 4.1 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/medicine/fulldata/adapter/merged --data data/AdaptEval/medicine_mcqa_random_5k.json --max-samples 1000 --output /content/v2_dynamic_ce/saves_beat_tlm/medicine/fulldata/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  52%|█████▏    | 248/473 [00:00<00:00, 2448.22it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3396.66it/s]
# generated 200/1000
# generated 400/1000
# generated 600/1000
# generated 800/1000
# generated 1000/1000
# 1000 prompts in 12.4s
# -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/fulldata/preds_adapted.jsonl
# rc=0 0.3 min
# medicine features + base + tlm + fulldata ready
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_build_pool.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/geography_mmlu.json --dataset geography --max-samples 225 --out-dir /content/v2_dynamic_ce/saves_beat_tlm/geography/pool
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  53%|█████▎    | 252/473 [00:00<00:00, 2514.16it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3422.67it/s]
# 225 usable items from 225 records
# capacity=23 init=3 warmup=30 grad_budget=92
#   proxy 100/225 | 8.2/s
#   proxy 200/225 | 8.3/s
# {
#   "dataset": "geography",
#   "model": "Qwen/Qwen3.5-0.8B",
#   "n": 225,
#   "capacity": 23,
#   "init_count": 3,
#   "warmup": 30,
#   "gradient_budget": 92,
#   "gradients_computed": 92,
#   "shortlist": 62,
#   "final_pool": 23,
#   "route_counts": {
#     "base": 173,
#     "adapted": 52
#   }
# }
# rc=0 0.9 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/geography_mmlu.json --max-samples 225 --output /content/v2_dynamic_ce/saves_beat_tlm/geography/preds_base.jsonl --max-new-tokens 12
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  53%|█████▎    | 253/473 [00:00<00:00, 2521.04it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3447.05it/s]
# generated 200/225
# generated 225/225
# 225 prompts in 2.4s
# -> /content/v2_dynamic_ce/saves_beat_tlm/geography/preds_base.jsonl
# rc=0 0.1 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/geography_mmlu.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/geography/tlm/selection.json --max-samples 225 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/geography/tlm/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  55%|█████▍    | 258/473 [00:00<00:00, 2550.44it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3519.04it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 23 selected samples
# step 20/23 | loss 0.4677 | lr 2.48e-06 | 4.07 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/geography/tlm/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 94136.50it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/geography/tlm/adapter/merged
# rc=0 0.2 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/geography/tlm/adapter/merged --data data/AdaptEval/geography_mmlu.json --max-samples 225 --output /content/v2_dynamic_ce/saves_beat_tlm/geography/tlm/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  54%|█████▍    | 257/473 [00:00<00:00, 2562.95it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3483.82it/s]
# generated 200/225
# generated 225/225
# 225 prompts in 2.4s
# -> /content/v2_dynamic_ce/saves_beat_tlm/geography/tlm/preds_adapted.jsonl
# rc=0 0.1 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/geography_mmlu.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/geography/fulldata/selection.json --max-samples 225 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/geography/fulldata/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  62%|██████▏   | 293/473 [00:00<00:00, 2920.71it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3720.53it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 225 selected samples
# step 20/225 | loss 0.3247 | lr 4.55e-05 | 4.07 it/s
# step 40/225 | loss 0.3432 | lr 4.90e-05 | 4.29 it/s
# step 60/225 | loss 0.2421 | lr 4.58e-05 | 4.36 it/s
# step 80/225 | loss 0.4159 | lr 4.06e-05 | 4.40 it/s
# step 100/225 | loss 0.3397 | lr 3.39e-05 | 4.42 it/s
# step 120/225 | loss 0.4129 | lr 2.64e-05 | 4.49 it/s
# step 140/225 | loss 0.4520 | lr 1.87e-05 | 4.55 it/s
# step 160/225 | loss 0.3214 | lr 1.16e-05 | 4.57 it/s
# step 180/225 | loss 0.3450 | lr 5.82e-06 | 4.61 it/s
# step 200/225 | loss 0.3501 | lr 1.85e-06 | 4.64 it/s
# step 220/225 | loss 0.2819 | lr 7.48e-08 | 4.67 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/geography/fulldata/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 37711.02it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/geography/fulldata/adapter/merged
# rc=0 0.9 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/geography/fulldata/adapter/merged --data data/AdaptEval/geography_mmlu.json --max-samples 225 --output /content/v2_dynamic_ce/saves_beat_tlm/geography/fulldata/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  85%|████████▍ | 400/473 [00:00<00:00, 3994.50it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4299.30it/s]
# generated 200/225
# generated 225/225
# 225 prompts in 2.4s
# -> /content/v2_dynamic_ce/saves_beat_tlm/geography/fulldata/preds_adapted.jsonl
# rc=0 0.1 min
# geography features + base + tlm + fulldata ready

# %%
def embed_items(ds, idxs):
    import torch, gc
    recs = json.load(open(DATA_FILES[ds]))[: N_BY_DATASET[ds]]
    m, tok = load_base(); dev = next(m.parameters()).device; tok.padding_side = "left"
    def wrap(t):
        try: return tok.apply_chat_template([{"role":"user","content":t}], tokenize=False, add_generation_prompt=True)
        except Exception: return t
    embs = []
    with torch.no_grad():
        for s in range(0, len(idxs), 32):
            ch = idxs[s:s+32]
            enc = tok([wrap(_build_user(recs[i])) for i in ch], return_tensors="pt", padding=True,
                      truncation=True, max_length=1024).to(dev)
            hs = m(**enc, output_hidden_states=True, use_cache=False).hidden_states[-1].float()
            mask = enc["attention_mask"].unsqueeze(-1).float()
            embs.append(((hs*mask).sum(1)/mask.sum(1).clamp(min=1)).cpu().numpy())
    del m; gc.collect(); torch.cuda.empty_cache()
    X = np.concatenate(embs); return X / (np.linalg.norm(X,axis=1,keepdims=True)+1e-8)

def write_sel(path, idxs):
    Path(path).parent.mkdir(parents=True, exist_ok=True)
    json.dump({"selected":[{"idx":int(i),"weight":1.0} for i in idxs]}, open(path,"w"))

for ds in DATASETS:
    idx = [json.loads(l)["idx"] for l in open(ROOT/ds/"pool"/"features.jsonl") if l.strip()]
    for arm, mode in SOUP_ARMS.items():
        adir = ROOT/ds/arm; adir.mkdir(parents=True, exist_ok=True)
        if all((adir/f"slice{j}"/"selection.json").exists() for j in range(K)): continue
        if mode == "seed":
            slices = [idx]*K                                   # same data, seeds differ at train time
        elif mode == "random":
            rng = np.random.RandomState(0); p = rng.permutation(idx)
            slices = [list(p[j::K]) for j in range(K)]         # K interleaved random splits
        else:  # kmeans
            from sklearn.cluster import KMeans
            X = embed_items(ds, idx)
            lab = KMeans(K, n_init=5, random_state=0).fit_predict(X)
            slices = [[idx[i] for i in range(len(idx)) if lab[i]==j] for j in range(K)]
            slices = [s if len(s)>=8 else idx for s in slices]  # guard tiny clusters
        for j, sl in enumerate(slices):
            write_sel(adir/f"slice{j}"/"selection.json", sl)
        print(f"{ds}/{arm}: slice sizes {[len(s) for s in slices]}")
# Out:
# logiqa/soup_seed: slice sizes [1000, 1000, 1000]
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# logiqa/soup_kmeans: slice sizes [423, 321, 256]
# logiqa/soup_random: slice sizes [334, 333, 333]
# medicine/soup_seed: slice sizes [1000, 1000, 1000]
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# medicine/soup_kmeans: slice sizes [407, 136, 457]
# medicine/soup_random: slice sizes [334, 333, 333]
# geography/soup_seed: slice sizes [225, 225, 225]
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# geography/soup_kmeans: slice sizes [50, 74, 101]
# geography/soup_random: slice sizes [75, 75, 75]

# %% [markdown]
# ## 2) Train K slice-adapters per arm (deletes per-slice merged to save disk)

# %%
for ds in DATASETS:
    for arm, mode in SOUP_ARMS.items():
        for j in range(K):
            sd = ROOT/ds/arm/f"slice{j}"; ad = sd/"adapter"
            if (ad/"adapter_model.safetensors").exists() or (ad/"adapter_model.bin").exists():
                continue
            sh([sys.executable, str(SCRIPTS/"ab_train_ttl_anchored.py"), "--model", MODEL,
                "--data", DATA_FILES[ds], "--selection-file", str(sd/"selection.json"),
                "--max-samples", str(N_BY_DATASET[ds]), "--output-dir", str(ad),
                "--lora-rank", "8", "--lora-alpha", "16", "--lora-keys", QV,
                "--epochs", str(EPOCHS), "--learning-rate", str(LR), "--anchor-lambda", "0.0",
                "--seed", str(j)], LOG/f"{ds}_{arm}_s{j}_train.log")     # seed=j => soup_seed diversity
            if (ad/"merged").exists(): shutil.rmtree(ad/"merged", ignore_errors=True)  # keep only adapter
        print(ds, arm, "adapters ready")
# Out:
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/logiqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/slice0/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/slice0/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  77%|███████▋  | 364/473 [00:00<00:00, 3631.01it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4098.51it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 1000 selected samples
# step 20/1000 | loss 0.5134 | lr 1.00e-05 | 3.75 it/s
# step 40/1000 | loss 0.6688 | lr 2.00e-05 | 3.95 it/s
# step 60/1000 | loss 0.6107 | lr 3.00e-05 | 4.00 it/s
# step 80/1000 | loss 0.4385 | lr 4.00e-05 | 4.03 it/s
# step 100/1000 | loss 0.4939 | lr 5.00e-05 | 4.01 it/s
# step 120/1000 | loss 0.3908 | lr 4.99e-05 | 4.04 it/s
# step 140/1000 | loss 0.4515 | lr 4.98e-05 | 4.06 it/s
# step 160/1000 | loss 0.4443 | lr 4.95e-05 | 4.07 it/s
# step 180/1000 | loss 0.4556 | lr 4.90e-05 | 4.06 it/s
# step 200/1000 | loss 0.4744 | lr 4.85e-05 | 4.07 it/s
# step 220/1000 | loss 0.4355 | lr 4.78e-05 | 4.07 it/s
# step 240/1000 | loss 0.4732 | lr 4.71e-05 | 4.06 it/s
# step 260/1000 | loss 0.3995 | lr 4.62e-05 | 4.07 it/s
# step 280/1000 | loss 0.4447 | lr 4.52e-05 | 4.08 it/s
# step 300/1000 | loss 0.3664 | lr 4.42e-05 | 4.08 it/s
# step 320/1000 | loss 0.4116 | lr 4.30e-05 | 4.09 it/s
# step 340/1000 | loss 0.4178 | lr 4.17e-05 | 4.08 it/s
# step 360/1000 | loss 0.4261 | lr 4.04e-05 | 4.09 it/s
# step 380/1000 | loss 0.4057 | lr 3.90e-05 | 4.09 it/s
# step 400/1000 | loss 0.4372 | lr 3.75e-05 | 4.10 it/s
# step 420/1000 | loss 0.4568 | lr 3.60e-05 | 4.10 it/s
# step 440/1000 | loss 0.3798 | lr 3.44e-05 | 4.10 it/s
# step 460/1000 | loss 0.3767 | lr 3.27e-05 | 4.10 it/s
# step 480/1000 | loss 0.4084 | lr 3.10e-05 | 4.11 it/s
# step 500/1000 | loss 0.4128 | lr 2.93e-05 | 4.11 it/s
# step 520/1000 | loss 0.4112 | lr 2.76e-05 | 4.10 it/s
# step 540/1000 | loss 0.4049 | lr 2.59e-05 | 4.10 it/s
# step 560/1000 | loss 0.4454 | lr 2.41e-05 | 4.10 it/s
# step 580/1000 | loss 0.4360 | lr 2.24e-05 | 4.11 it/s
# step 600/1000 | loss 0.4751 | lr 2.07e-05 | 4.11 it/s
# step 620/1000 | loss 0.4418 | lr 1.90e-05 | 4.11 it/s
# step 640/1000 | loss 0.3885 | lr 1.73e-05 | 4.11 it/s
# step 660/1000 | loss 0.4666 | lr 1.56e-05 | 4.11 it/s
# step 680/1000 | loss 0.4367 | lr 1.40e-05 | 4.11 it/s
# step 700/1000 | loss 0.4299 | lr 1.25e-05 | 4.11 it/s
# step 720/1000 | loss 0.4181 | lr 1.10e-05 | 4.11 it/s
# step 740/1000 | loss 0.5419 | lr 9.61e-06 | 4.11 it/s
# step 760/1000 | loss 0.4209 | lr 8.27e-06 | 4.11 it/s
# step 780/1000 | loss 0.3550 | lr 7.02e-06 | 4.11 it/s
# step 800/1000 | loss 0.3824 | lr 5.85e-06 | 4.11 it/s
# step 820/1000 | loss 0.4598 | lr 4.77e-06 | 4.11 it/s
# step 840/1000 | loss 0.4204 | lr 3.80e-06 | 4.11 it/s
# step 860/1000 | loss 0.3277 | lr 2.93e-06 | 4.11 it/s
# step 880/1000 | loss 0.4285 | lr 2.16e-06 | 4.11 it/s
# step 900/1000 | loss 0.3561 | lr 1.51e-06 | 4.11 it/s
# step 920/1000 | loss 0.3859 | lr 9.68e-07 | 4.11 it/s
# step 940/1000 | loss 0.4030 | lr 5.46e-07 | 4.11 it/s
# step 960/1000 | loss 0.3667 | lr 2.43e-07 | 4.11 it/s
# step 980/1000 | loss 0.3545 | lr 6.09e-08 | 4.11 it/s
# step 1000/1000 | loss 0.4395 | lr 0.00e+00 | 4.11 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/slice0/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 41345.82it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/slice0/adapter/merged
# rc=0 4.2 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/logiqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/slice1/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/slice1/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 1
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  55%|█████▍    | 259/473 [00:00<00:00, 2576.60it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3532.26it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 1000 selected samples
# step 20/1000 | loss 0.6117 | lr 1.00e-05 | 3.80 it/s
# step 40/1000 | loss 0.5661 | lr 2.00e-05 | 3.99 it/s
# step 60/1000 | loss 0.4115 | lr 3.00e-05 | 4.04 it/s
# step 80/1000 | loss 0.4467 | lr 4.00e-05 | 4.08 it/s
# step 100/1000 | loss 0.4127 | lr 5.00e-05 | 4.08 it/s
# step 120/1000 | loss 0.4564 | lr 4.99e-05 | 4.09 it/s
# step 140/1000 | loss 0.4052 | lr 4.98e-05 | 4.10 it/s
# step 160/1000 | loss 0.4794 | lr 4.95e-05 | 4.11 it/s
# step 180/1000 | loss 0.4552 | lr 4.90e-05 | 4.12 it/s
# step 200/1000 | loss 0.4015 | lr 4.85e-05 | 4.12 it/s
# step 220/1000 | loss 0.3976 | lr 4.78e-05 | 4.12 it/s
# step 240/1000 | loss 0.4289 | lr 4.71e-05 | 4.11 it/s
# step 260/1000 | loss 0.4565 | lr 4.62e-05 | 4.12 it/s
# step 280/1000 | loss 0.3385 | lr 4.52e-05 | 4.12 it/s
# step 300/1000 | loss 0.4168 | lr 4.42e-05 | 4.13 it/s
# step 320/1000 | loss 0.5185 | lr 4.30e-05 | 4.13 it/s
# step 340/1000 | loss 0.4889 | lr 4.17e-05 | 4.12 it/s
# step 360/1000 | loss 0.4375 | lr 4.04e-05 | 4.12 it/s
# step 380/1000 | loss 0.4340 | lr 3.90e-05 | 4.13 it/s
# step 400/1000 | loss 0.4248 | lr 3.75e-05 | 4.13 it/s
# step 420/1000 | loss 0.4477 | lr 3.60e-05 | 4.13 it/s
# step 440/1000 | loss 0.4501 | lr 3.44e-05 | 4.13 it/s
# step 460/1000 | loss 0.4441 | lr 3.27e-05 | 4.13 it/s
# step 480/1000 | loss 0.4081 | lr 3.10e-05 | 4.13 it/s
# step 500/1000 | loss 0.3916 | lr 2.93e-05 | 4.13 it/s
# step 520/1000 | loss 0.3593 | lr 2.76e-05 | 4.13 it/s
# step 540/1000 | loss 0.4239 | lr 2.59e-05 | 4.13 it/s
# step 560/1000 | loss 0.4680 | lr 2.41e-05 | 4.13 it/s
# step 580/1000 | loss 0.4363 | lr 2.24e-05 | 4.13 it/s
# step 600/1000 | loss 0.4191 | lr 2.07e-05 | 4.13 it/s
# step 620/1000 | loss 0.3798 | lr 1.90e-05 | 4.13 it/s
# step 640/1000 | loss 0.4641 | lr 1.73e-05 | 4.13 it/s
# step 660/1000 | loss 0.4757 | lr 1.56e-05 | 4.13 it/s
# step 680/1000 | loss 0.4583 | lr 1.40e-05 | 4.13 it/s
# step 700/1000 | loss 0.4415 | lr 1.25e-05 | 4.13 it/s
# step 720/1000 | loss 0.3867 | lr 1.10e-05 | 4.13 it/s
# step 740/1000 | loss 0.4348 | lr 9.61e-06 | 4.13 it/s
# step 760/1000 | loss 0.3910 | lr 8.27e-06 | 4.14 it/s
# step 780/1000 | loss 0.4401 | lr 7.02e-06 | 4.15 it/s
# step 800/1000 | loss 0.4105 | lr 5.85e-06 | 4.16 it/s
# step 820/1000 | loss 0.3810 | lr 4.77e-06 | 4.16 it/s
# step 840/1000 | loss 0.4031 | lr 3.80e-06 | 4.17 it/s
# step 860/1000 | loss 0.3694 | lr 2.93e-06 | 4.18 it/s
# step 880/1000 | loss 0.4438 | lr 2.16e-06 | 4.18 it/s
# step 900/1000 | loss 0.3934 | lr 1.51e-06 | 4.19 it/s
# step 920/1000 | loss 0.4689 | lr 9.68e-07 | 4.20 it/s
# step 940/1000 | loss 0.4095 | lr 5.46e-07 | 4.20 it/s
# step 960/1000 | loss 0.4063 | lr 2.43e-07 | 4.20 it/s
# step 980/1000 | loss 0.3283 | lr 6.09e-08 | 4.21 it/s
# step 1000/1000 | loss 0.4076 | lr 0.00e+00 | 4.22 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/slice1/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 94608.36it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/slice1/adapter/merged
# rc=0 4.1 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/logiqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/slice2/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/slice2/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 2
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  76%|███████▌  | 358/473 [00:00<00:00, 3578.37it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4066.52it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 1000 selected samples
# step 20/1000 | loss 0.5879 | lr 1.00e-05 | 3.79 it/s
# step 40/1000 | loss 0.5043 | lr 2.00e-05 | 3.97 it/s
# step 60/1000 | loss 0.3612 | lr 3.00e-05 | 4.02 it/s
# step 80/1000 | loss 0.4973 | lr 4.00e-05 | 4.05 it/s
# step 100/1000 | loss 0.4058 | lr 5.00e-05 | 4.05 it/s
# step 120/1000 | loss 0.4497 | lr 4.99e-05 | 4.07 it/s
# step 140/1000 | loss 0.3850 | lr 4.98e-05 | 4.09 it/s
# step 160/1000 | loss 0.4429 | lr 4.95e-05 | 4.09 it/s
# step 180/1000 | loss 0.4074 | lr 4.90e-05 | 4.10 it/s
# step 200/1000 | loss 0.4062 | lr 4.85e-05 | 4.09 it/s
# step 220/1000 | loss 0.4338 | lr 4.78e-05 | 4.10 it/s
# step 240/1000 | loss 0.4803 | lr 4.71e-05 | 4.10 it/s
# step 260/1000 | loss 0.4531 | lr 4.62e-05 | 4.11 it/s
# step 280/1000 | loss 0.4112 | lr 4.52e-05 | 4.11 it/s
# step 300/1000 | loss 0.4584 | lr 4.42e-05 | 4.11 it/s
# step 320/1000 | loss 0.4195 | lr 4.30e-05 | 4.11 it/s
# step 340/1000 | loss 0.4591 | lr 4.17e-05 | 4.11 it/s
# step 360/1000 | loss 0.4353 | lr 4.04e-05 | 4.10 it/s
# step 380/1000 | loss 0.4530 | lr 3.90e-05 | 4.10 it/s
# step 400/1000 | loss 0.4273 | lr 3.75e-05 | 4.10 it/s
# step 420/1000 | loss 0.4350 | lr 3.60e-05 | 4.10 it/s
# step 440/1000 | loss 0.4351 | lr 3.44e-05 | 4.10 it/s
# step 460/1000 | loss 0.4693 | lr 3.27e-05 | 4.10 it/s
# step 480/1000 | loss 0.3841 | lr 3.10e-05 | 4.10 it/s
# step 500/1000 | loss 0.3881 | lr 2.93e-05 | 4.10 it/s
# step 520/1000 | loss 0.4508 | lr 2.76e-05 | 4.10 it/s
# step 540/1000 | loss 0.4126 | lr 2.59e-05 | 4.10 it/s
# step 560/1000 | loss 0.3906 | lr 2.41e-05 | 4.10 it/s
# step 580/1000 | loss 0.4898 | lr 2.24e-05 | 4.10 it/s
# step 600/1000 | loss 0.3726 | lr 2.07e-05 | 4.11 it/s
# step 620/1000 | loss 0.3939 | lr 1.90e-05 | 4.11 it/s
# step 640/1000 | loss 0.4585 | lr 1.73e-05 | 4.11 it/s
# step 660/1000 | loss 0.5257 | lr 1.56e-05 | 4.10 it/s
# step 680/1000 | loss 0.4225 | lr 1.40e-05 | 4.10 it/s
# step 700/1000 | loss 0.3639 | lr 1.25e-05 | 4.11 it/s
# step 720/1000 | loss 0.4900 | lr 1.10e-05 | 4.11 it/s
# step 740/1000 | loss 0.4245 | lr 9.61e-06 | 4.11 it/s
# step 760/1000 | loss 0.3768 | lr 8.27e-06 | 4.11 it/s
# step 780/1000 | loss 0.3982 | lr 7.02e-06 | 4.11 it/s
# step 800/1000 | loss 0.3513 | lr 5.85e-06 | 4.11 it/s
# step 820/1000 | loss 0.4372 | lr 4.77e-06 | 4.11 it/s
# step 840/1000 | loss 0.4702 | lr 3.80e-06 | 4.12 it/s
# step 860/1000 | loss 0.3961 | lr 2.93e-06 | 4.12 it/s
# step 880/1000 | loss 0.4016 | lr 2.16e-06 | 4.13 it/s
# step 900/1000 | loss 0.4296 | lr 1.51e-06 | 4.14 it/s
# step 920/1000 | loss 0.4714 | lr 9.68e-07 | 4.14 it/s
# step 940/1000 | loss 0.3946 | lr 5.46e-07 | 4.15 it/s
# step 960/1000 | loss 0.3615 | lr 2.43e-07 | 4.15 it/s
# step 980/1000 | loss 0.4304 | lr 6.09e-08 | 4.16 it/s
# step 1000/1000 | loss 0.3486 | lr 0.00e+00 | 4.17 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/slice2/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 14369.52it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/slice2/adapter/merged
# rc=0 4.1 min
# logiqa soup_seed adapters ready
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/logiqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/slice0/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/slice0/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  62%|██████▏   | 292/473 [00:00<00:00, 2908.66it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3765.56it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 423 selected samples
# step 20/423 | loss 0.6240 | lr 2.38e-05 | 3.77 it/s
# step 40/423 | loss 0.4353 | lr 4.76e-05 | 3.96 it/s
# step 60/423 | loss 0.5289 | lr 4.97e-05 | 4.02 it/s
# step 80/423 | loss 0.4791 | lr 4.88e-05 | 4.00 it/s
# step 100/423 | loss 0.5064 | lr 4.72e-05 | 4.02 it/s
# step 120/423 | loss 0.3577 | lr 4.50e-05 | 4.05 it/s
# step 140/423 | loss 0.4412 | lr 4.23e-05 | 4.06 it/s
# step 160/423 | loss 0.3936 | lr 3.91e-05 | 4.06 it/s
# step 180/423 | loss 0.4173 | lr 3.55e-05 | 4.07 it/s
# step 200/423 | loss 0.3801 | lr 3.16e-05 | 4.08 it/s
# step 220/423 | loss 0.3996 | lr 2.76e-05 | 4.08 it/s
# step 240/423 | loss 0.4880 | lr 2.35e-05 | 4.07 it/s
# step 260/423 | loss 0.3437 | lr 1.94e-05 | 4.08 it/s
# step 280/423 | loss 0.4946 | lr 1.55e-05 | 4.08 it/s
# step 300/423 | loss 0.3830 | lr 1.18e-05 | 4.07 it/s
# step 320/423 | loss 0.4245 | lr 8.49e-06 | 4.08 it/s
# step 340/423 | loss 0.4391 | lr 5.63e-06 | 4.08 it/s
# step 360/423 | loss 0.4110 | lr 3.30e-06 | 4.09 it/s
# step 380/423 | loss 0.4136 | lr 1.56e-06 | 4.09 it/s
# step 400/423 | loss 0.3388 | lr 4.48e-07 | 4.09 it/s
# step 420/423 | loss 0.4373 | lr 7.65e-09 | 4.09 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/slice0/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 20616.46it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/slice0/adapter/merged
# rc=0 1.8 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/logiqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/slice1/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/slice1/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 1
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  56%|█████▌    | 265/473 [00:00<00:00, 2638.20it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3574.62it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 321 selected samples
# step 20/321 | loss 0.5698 | lr 3.13e-05 | 3.79 it/s
# step 40/321 | loss 0.5202 | lr 4.99e-05 | 3.98 it/s
# step 60/321 | loss 0.5215 | lr 4.89e-05 | 4.04 it/s
# step 80/321 | loss 0.5716 | lr 4.67e-05 | 4.07 it/s
# step 100/321 | loss 0.4639 | lr 4.35e-05 | 4.13 it/s
# step 120/321 | loss 0.4061 | lr 3.94e-05 | 4.20 it/s
# step 140/321 | loss 0.4627 | lr 3.47e-05 | 4.25 it/s
# step 160/321 | loss 0.4592 | lr 2.95e-05 | 4.26 it/s
# step 180/321 | loss 0.4548 | lr 2.40e-05 | 4.28 it/s
# step 200/321 | loss 0.4458 | lr 1.87e-05 | 4.31 it/s
# step 220/321 | loss 0.4561 | lr 1.36e-05 | 4.33 it/s
# step 240/321 | loss 0.3995 | lr 9.08e-06 | 4.34 it/s
# step 260/321 | loss 0.4144 | lr 5.30e-06 | 4.35 it/s
# step 280/321 | loss 0.4675 | lr 2.44e-06 | 4.35 it/s
# step 300/321 | loss 0.4532 | lr 6.49e-07 | 4.37 it/s
# step 320/321 | loss 0.4538 | lr 1.48e-09 | 4.37 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/slice1/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 36792.14it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/slice1/adapter/merged
# rc=0 1.3 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/logiqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/slice2/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/slice2/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 2
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  64%|██████▍   | 303/473 [00:00<00:00, 3026.47it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3799.28it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 256 selected samples
# step 20/256 | loss 0.5947 | lr 4.00e-05 | 3.75 it/s
# step 40/256 | loss 0.4242 | lr 4.95e-05 | 3.93 it/s
# step 60/256 | loss 0.4197 | lr 4.72e-05 | 3.98 it/s
# step 80/256 | loss 0.4923 | lr 4.33e-05 | 4.01 it/s
# step 100/256 | loss 0.3087 | lr 3.81e-05 | 4.03 it/s
# step 120/256 | loss 0.4155 | lr 3.19e-05 | 4.02 it/s
# step 140/256 | loss 0.4466 | lr 2.52e-05 | 4.04 it/s
# step 160/256 | loss 0.4019 | lr 1.84e-05 | 4.05 it/s
# step 180/256 | loss 0.4249 | lr 1.22e-05 | 4.06 it/s
# step 200/256 | loss 0.4523 | lr 6.91e-06 | 4.07 it/s
# step 220/256 | loss 0.4246 | lr 2.94e-06 | 4.06 it/s
# step 240/256 | loss 0.4232 | lr 5.90e-07 | 4.07 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/slice2/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 169276.84it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/slice2/adapter/merged
# rc=0 1.2 min
# logiqa soup_kmeans adapters ready
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/logiqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/slice0/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/slice0/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  54%|█████▎    | 254/473 [00:00<00:00, 2529.67it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3457.79it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 334 selected samples
# step 20/334 | loss 0.6377 | lr 3.03e-05 | 3.82 it/s
# step 40/334 | loss 0.5286 | lr 4.99e-05 | 3.95 it/s
# step 60/334 | loss 0.4693 | lr 4.90e-05 | 3.98 it/s
# step 80/334 | loss 0.5025 | lr 4.71e-05 | 3.99 it/s
# step 100/334 | loss 0.4781 | lr 4.41e-05 | 4.06 it/s
# step 120/334 | loss 0.4282 | lr 4.04e-05 | 4.13 it/s
# step 140/334 | loss 0.4289 | lr 3.60e-05 | 4.17 it/s
# step 160/334 | loss 0.4384 | lr 3.11e-05 | 4.18 it/s
# step 180/334 | loss 0.4345 | lr 2.59e-05 | 4.22 it/s
# step 200/334 | loss 0.3959 | lr 2.07e-05 | 4.25 it/s
# step 220/334 | loss 0.4080 | lr 1.57e-05 | 4.25 it/s
# step 240/334 | loss 0.3594 | lr 1.11e-05 | 4.27 it/s
# step 260/334 | loss 0.3587 | lr 7.09e-06 | 4.29 it/s
# step 280/334 | loss 0.3816 | lr 3.87e-06 | 4.29 it/s
# step 300/334 | loss 0.4808 | lr 1.56e-06 | 4.31 it/s
# step 320/334 | loss 0.4270 | lr 2.66e-07 | 4.32 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/slice0/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 33465.19it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/slice0/adapter/merged
# rc=0 1.4 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/logiqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/slice1/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/slice1/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 1
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  66%|██████▌   | 311/473 [00:00<00:00, 3094.47it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3913.70it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 333 selected samples
# step 20/333 | loss 0.4889 | lr 3.03e-05 | 3.82 it/s
# step 40/333 | loss 0.5268 | lr 4.99e-05 | 3.98 it/s
# step 60/333 | loss 0.4711 | lr 4.90e-05 | 4.03 it/s
# step 80/333 | loss 0.5131 | lr 4.70e-05 | 4.07 it/s
# step 100/333 | loss 0.3946 | lr 4.41e-05 | 4.08 it/s
# step 120/333 | loss 0.3869 | lr 4.03e-05 | 4.09 it/s
# step 140/333 | loss 0.4504 | lr 3.59e-05 | 4.10 it/s
# step 160/333 | loss 0.3820 | lr 3.10e-05 | 4.11 it/s
# step 180/333 | loss 0.4147 | lr 2.58e-05 | 4.09 it/s
# step 200/333 | loss 0.5025 | lr 2.06e-05 | 4.10 it/s
# step 220/333 | loss 0.4305 | lr 1.56e-05 | 4.11 it/s
# step 240/333 | loss 0.4715 | lr 1.09e-05 | 4.11 it/s
# step 260/333 | loss 0.4619 | lr 6.96e-06 | 4.11 it/s
# step 280/333 | loss 0.4108 | lr 3.75e-06 | 4.12 it/s
# step 300/333 | loss 0.4381 | lr 1.48e-06 | 4.11 it/s
# step 320/333 | loss 0.4182 | lr 2.31e-07 | 4.11 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/slice1/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 29194.69it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/slice1/adapter/merged
# rc=0 1.5 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/logiqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/slice2/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/slice2/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 2
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  74%|███████▍  | 352/473 [00:00<00:00, 3507.29it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4033.30it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 333 selected samples
# step 20/333 | loss 0.7056 | lr 3.03e-05 | 3.73 it/s
# step 40/333 | loss 0.4618 | lr 4.99e-05 | 3.91 it/s
# step 60/333 | loss 0.3581 | lr 4.90e-05 | 4.00 it/s
# step 80/333 | loss 0.5369 | lr 4.70e-05 | 4.03 it/s
# step 100/333 | loss 0.4394 | lr 4.41e-05 | 4.02 it/s
# step 120/333 | loss 0.3942 | lr 4.03e-05 | 4.04 it/s
# step 140/333 | loss 0.4581 | lr 3.59e-05 | 4.05 it/s
# step 160/333 | loss 0.4694 | lr 3.10e-05 | 4.07 it/s
# step 180/333 | loss 0.4182 | lr 2.58e-05 | 4.08 it/s
# step 200/333 | loss 0.3923 | lr 2.06e-05 | 4.08 it/s
# step 220/333 | loss 0.4909 | lr 1.56e-05 | 4.08 it/s
# step 240/333 | loss 0.4161 | lr 1.09e-05 | 4.08 it/s
# step 260/333 | loss 0.4831 | lr 6.96e-06 | 4.09 it/s
# step 280/333 | loss 0.4164 | lr 3.75e-06 | 4.10 it/s
# step 300/333 | loss 0.3904 | lr 1.48e-06 | 4.09 it/s
# step 320/333 | loss 0.4251 | lr 2.31e-07 | 4.09 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/slice2/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 167029.81it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/slice2/adapter/merged
# rc=0 1.5 min
# logiqa soup_random adapters ready
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/medicine_mcqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/slice0/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/slice0/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  76%|███████▌  | 358/473 [00:00<00:00, 3576.39it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4068.82it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 1000 selected samples
# step 20/1000 | loss 0.7939 | lr 1.00e-05 | 3.79 it/s
# step 40/1000 | loss 0.8915 | lr 2.00e-05 | 3.92 it/s
# step 60/1000 | loss 0.8904 | lr 3.00e-05 | 3.97 it/s
# step 80/1000 | loss 0.5304 | lr 4.00e-05 | 4.00 it/s
# step 100/1000 | loss 0.4429 | lr 5.00e-05 | 3.98 it/s
# step 120/1000 | loss 0.4502 | lr 4.99e-05 | 3.98 it/s
# step 140/1000 | loss 0.3480 | lr 4.98e-05 | 4.00 it/s
# step 160/1000 | loss 0.3909 | lr 4.95e-05 | 4.02 it/s
# step 180/1000 | loss 0.5249 | lr 4.90e-05 | 4.02 it/s
# step 200/1000 | loss 0.4339 | lr 4.85e-05 | 4.02 it/s
# step 220/1000 | loss 0.3866 | lr 4.78e-05 | 4.02 it/s
# step 240/1000 | loss 0.4088 | lr 4.71e-05 | 4.02 it/s
# step 260/1000 | loss 0.4239 | lr 4.62e-05 | 4.03 it/s
# step 280/1000 | loss 0.4293 | lr 4.52e-05 | 4.02 it/s
# step 300/1000 | loss 0.4027 | lr 4.42e-05 | 4.02 it/s
# step 320/1000 | loss 0.4656 | lr 4.30e-05 | 4.02 it/s
# step 340/1000 | loss 0.4223 | lr 4.17e-05 | 4.03 it/s
# step 360/1000 | loss 0.4380 | lr 4.04e-05 | 4.03 it/s
# step 380/1000 | loss 0.5693 | lr 3.90e-05 | 4.03 it/s
# step 400/1000 | loss 0.3898 | lr 3.75e-05 | 4.03 it/s
# step 420/1000 | loss 0.4686 | lr 3.60e-05 | 4.04 it/s
# step 440/1000 | loss 0.4640 | lr 3.44e-05 | 4.04 it/s
# step 460/1000 | loss 0.4458 | lr 3.27e-05 | 4.03 it/s
# step 480/1000 | loss 0.4674 | lr 3.10e-05 | 4.03 it/s
# step 500/1000 | loss 0.4040 | lr 2.93e-05 | 4.05 it/s
# step 520/1000 | loss 0.4388 | lr 2.76e-05 | 4.06 it/s
# step 540/1000 | loss 0.3986 | lr 2.59e-05 | 4.08 it/s
# step 560/1000 | loss 0.4423 | lr 2.41e-05 | 4.08 it/s
# step 580/1000 | loss 0.3722 | lr 2.24e-05 | 4.09 it/s
# step 600/1000 | loss 0.4528 | lr 2.07e-05 | 4.10 it/s
# step 620/1000 | loss 0.3765 | lr 1.90e-05 | 4.11 it/s
# step 640/1000 | loss 0.4003 | lr 1.73e-05 | 4.12 it/s
# step 660/1000 | loss 0.3839 | lr 1.56e-05 | 4.12 it/s
# step 680/1000 | loss 0.4311 | lr 1.40e-05 | 4.13 it/s
# step 700/1000 | loss 0.4259 | lr 1.25e-05 | 4.14 it/s
# step 720/1000 | loss 0.3962 | lr 1.10e-05 | 4.15 it/s
# step 740/1000 | loss 0.4498 | lr 9.61e-06 | 4.16 it/s
# step 760/1000 | loss 0.4239 | lr 8.27e-06 | 4.16 it/s
# step 780/1000 | loss 0.4224 | lr 7.02e-06 | 4.17 it/s
# step 800/1000 | loss 0.3961 | lr 5.85e-06 | 4.17 it/s
# step 820/1000 | loss 0.4340 | lr 4.77e-06 | 4.18 it/s
# step 840/1000 | loss 0.3909 | lr 3.80e-06 | 4.18 it/s
# step 860/1000 | loss 0.3818 | lr 2.93e-06 | 4.19 it/s
# step 880/1000 | loss 0.4263 | lr 2.16e-06 | 4.19 it/s
# step 900/1000 | loss 0.3657 | lr 1.51e-06 | 4.19 it/s
# step 920/1000 | loss 0.3747 | lr 9.68e-07 | 4.20 it/s
# step 940/1000 | loss 0.3489 | lr 5.46e-07 | 4.20 it/s
# step 960/1000 | loss 0.4528 | lr 2.43e-07 | 4.21 it/s
# step 980/1000 | loss 0.4567 | lr 6.09e-08 | 4.21 it/s
# step 1000/1000 | loss 0.3941 | lr 0.00e+00 | 4.21 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/slice0/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 14074.85it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/slice0/adapter/merged
# rc=0 4.1 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/medicine_mcqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/slice1/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/slice1/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 1
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  59%|█████▉    | 278/473 [00:00<00:00, 2762.49it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3613.26it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 1000 selected samples
# step 20/1000 | loss 0.8024 | lr 1.00e-05 | 3.69 it/s
# step 40/1000 | loss 1.0979 | lr 2.00e-05 | 3.91 it/s
# step 60/1000 | loss 0.6226 | lr 3.00e-05 | 3.96 it/s
# step 80/1000 | loss 0.4929 | lr 4.00e-05 | 4.01 it/s
# step 100/1000 | loss 0.3573 | lr 5.00e-05 | 4.03 it/s
# step 120/1000 | loss 0.4765 | lr 4.99e-05 | 4.03 it/s
# step 140/1000 | loss 0.4419 | lr 4.98e-05 | 4.04 it/s
# step 160/1000 | loss 0.4794 | lr 4.95e-05 | 4.05 it/s
# step 180/1000 | loss 0.4340 | lr 4.90e-05 | 4.06 it/s
# step 200/1000 | loss 0.4478 | lr 4.85e-05 | 4.06 it/s
# step 220/1000 | loss 0.4094 | lr 4.78e-05 | 4.05 it/s
# step 240/1000 | loss 0.5353 | lr 4.71e-05 | 4.05 it/s
# step 260/1000 | loss 0.4605 | lr 4.62e-05 | 4.05 it/s
# step 280/1000 | loss 0.4162 | lr 4.52e-05 | 4.05 it/s
# step 300/1000 | loss 0.3708 | lr 4.42e-05 | 4.05 it/s
# step 320/1000 | loss 0.3649 | lr 4.30e-05 | 4.05 it/s
# step 340/1000 | loss 0.4164 | lr 4.17e-05 | 4.05 it/s
# step 360/1000 | loss 0.4424 | lr 4.04e-05 | 4.06 it/s
# step 380/1000 | loss 0.4052 | lr 3.90e-05 | 4.05 it/s
# step 400/1000 | loss 0.3838 | lr 3.75e-05 | 4.06 it/s
# step 420/1000 | loss 0.4202 | lr 3.60e-05 | 4.06 it/s
# step 440/1000 | loss 0.4913 | lr 3.44e-05 | 4.05 it/s
# step 460/1000 | loss 0.4960 | lr 3.27e-05 | 4.06 it/s
# step 480/1000 | loss 0.4593 | lr 3.10e-05 | 4.06 it/s
# step 500/1000 | loss 0.4256 | lr 2.93e-05 | 4.06 it/s
# step 520/1000 | loss 0.3681 | lr 2.76e-05 | 4.06 it/s
# step 540/1000 | loss 0.3541 | lr 2.59e-05 | 4.05 it/s
# step 560/1000 | loss 0.4395 | lr 2.41e-05 | 4.04 it/s
# step 580/1000 | loss 0.4654 | lr 2.24e-05 | 4.04 it/s
# step 600/1000 | loss 0.4107 | lr 2.07e-05 | 4.04 it/s
# step 620/1000 | loss 0.3611 | lr 1.90e-05 | 4.05 it/s
# step 640/1000 | loss 0.3994 | lr 1.73e-05 | 4.05 it/s
# step 660/1000 | loss 0.4203 | lr 1.56e-05 | 4.04 it/s
# step 680/1000 | loss 0.3866 | lr 1.40e-05 | 4.04 it/s
# step 700/1000 | loss 0.3804 | lr 1.25e-05 | 4.04 it/s
# step 720/1000 | loss 0.4551 | lr 1.10e-05 | 4.04 it/s
# step 740/1000 | loss 0.4043 | lr 9.61e-06 | 4.04 it/s
# step 760/1000 | loss 0.4008 | lr 8.27e-06 | 4.04 it/s
# step 780/1000 | loss 0.4608 | lr 7.02e-06 | 4.04 it/s
# step 800/1000 | loss 0.3423 | lr 5.85e-06 | 4.04 it/s
# step 820/1000 | loss 0.3596 | lr 4.77e-06 | 4.03 it/s
# step 840/1000 | loss 0.3884 | lr 3.80e-06 | 4.03 it/s
# step 860/1000 | loss 0.3942 | lr 2.93e-06 | 4.04 it/s
# step 880/1000 | loss 0.4082 | lr 2.16e-06 | 4.04 it/s
# step 900/1000 | loss 0.4597 | lr 1.51e-06 | 4.03 it/s
# step 920/1000 | loss 0.5095 | lr 9.68e-07 | 4.03 it/s
# step 940/1000 | loss 0.4791 | lr 5.46e-07 | 4.03 it/s
# step 960/1000 | loss 0.4406 | lr 2.43e-07 | 4.03 it/s
# step 980/1000 | loss 0.4260 | lr 6.09e-08 | 4.03 it/s
# step 1000/1000 | loss 0.4431 | lr 0.00e+00 | 4.03 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/slice1/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 47304.18it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/slice1/adapter/merged
# rc=0 4.3 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/medicine_mcqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/slice2/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/slice2/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 2
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  55%|█████▍    | 258/473 [00:00<00:00, 2566.71it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3514.72it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 1000 selected samples
# step 20/1000 | loss 0.9398 | lr 1.00e-05 | 3.63 it/s
# step 40/1000 | loss 0.8494 | lr 2.00e-05 | 3.85 it/s
# step 60/1000 | loss 0.9170 | lr 3.00e-05 | 3.91 it/s
# step 80/1000 | loss 0.4538 | lr 4.00e-05 | 3.96 it/s
# step 100/1000 | loss 0.4009 | lr 5.00e-05 | 3.95 it/s
# step 120/1000 | loss 0.5369 | lr 4.99e-05 | 3.95 it/s
# step 140/1000 | loss 0.4459 | lr 4.98e-05 | 3.96 it/s
# step 160/1000 | loss 0.4538 | lr 4.95e-05 | 3.98 it/s
# step 180/1000 | loss 0.4409 | lr 4.90e-05 | 3.98 it/s
# step 200/1000 | loss 0.4253 | lr 4.85e-05 | 4.02 it/s
# step 220/1000 | loss 0.4538 | lr 4.78e-05 | 4.04 it/s
# step 240/1000 | loss 0.3781 | lr 4.71e-05 | 4.07 it/s
# step 260/1000 | loss 0.4452 | lr 4.62e-05 | 4.10 it/s
# step 280/1000 | loss 0.4487 | lr 4.52e-05 | 4.11 it/s
# step 300/1000 | loss 0.4133 | lr 4.42e-05 | 4.12 it/s
# step 320/1000 | loss 0.4250 | lr 4.30e-05 | 4.14 it/s
# step 340/1000 | loss 0.4568 | lr 4.17e-05 | 4.16 it/s
# step 360/1000 | loss 0.4510 | lr 4.04e-05 | 4.17 it/s
# step 380/1000 | loss 0.4006 | lr 3.90e-05 | 4.18 it/s
# step 400/1000 | loss 0.4123 | lr 3.75e-05 | 4.18 it/s
# step 420/1000 | loss 0.3428 | lr 3.60e-05 | 4.19 it/s
# step 440/1000 | loss 0.4512 | lr 3.44e-05 | 4.20 it/s
# step 460/1000 | loss 0.4136 | lr 3.27e-05 | 4.20 it/s
# step 480/1000 | loss 0.3789 | lr 3.10e-05 | 4.20 it/s
# step 500/1000 | loss 0.4297 | lr 2.93e-05 | 4.21 it/s
# step 520/1000 | loss 0.3911 | lr 2.76e-05 | 4.22 it/s
# step 540/1000 | loss 0.3447 | lr 2.59e-05 | 4.22 it/s
# step 560/1000 | loss 0.4851 | lr 2.41e-05 | 4.22 it/s
# step 580/1000 | loss 0.3892 | lr 2.24e-05 | 4.22 it/s
# step 600/1000 | loss 0.4178 | lr 2.07e-05 | 4.23 it/s
# step 620/1000 | loss 0.3968 | lr 1.90e-05 | 4.23 it/s
# step 640/1000 | loss 0.4595 | lr 1.73e-05 | 4.23 it/s
# step 660/1000 | loss 0.3831 | lr 1.56e-05 | 4.24 it/s
# step 680/1000 | loss 0.4509 | lr 1.40e-05 | 4.24 it/s
# step 700/1000 | loss 0.4883 | lr 1.25e-05 | 4.24 it/s
# step 720/1000 | loss 0.4537 | lr 1.10e-05 | 4.25 it/s
# step 740/1000 | loss 0.3360 | lr 9.61e-06 | 4.25 it/s
# step 760/1000 | loss 0.3918 | lr 8.27e-06 | 4.25 it/s
# step 780/1000 | loss 0.4837 | lr 7.02e-06 | 4.25 it/s
# step 800/1000 | loss 0.3651 | lr 5.85e-06 | 4.25 it/s
# step 820/1000 | loss 0.4716 | lr 4.77e-06 | 4.25 it/s
# step 840/1000 | loss 0.4746 | lr 3.80e-06 | 4.25 it/s
# step 860/1000 | loss 0.4080 | lr 2.93e-06 | 4.25 it/s
# step 880/1000 | loss 0.4422 | lr 2.16e-06 | 4.26 it/s
# step 900/1000 | loss 0.4610 | lr 1.51e-06 | 4.26 it/s
# step 920/1000 | loss 0.4201 | lr 9.68e-07 | 4.26 it/s
# step 940/1000 | loss 0.4013 | lr 5.46e-07 | 4.26 it/s
# step 960/1000 | loss 0.4344 | lr 2.43e-07 | 4.26 it/s
# step 980/1000 | loss 0.4099 | lr 6.09e-08 | 4.26 it/s
# step 1000/1000 | loss 0.4167 | lr 0.00e+00 | 4.26 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/slice2/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 32939.56it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/slice2/adapter/merged
# rc=0 4.0 min
# medicine soup_seed adapters ready
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/medicine_mcqa_random_5k.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_kmeans/slice0/selection.json --max-samples 1000 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_kmeans/slice0/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  68%|██████▊   | 323/473 [00:00<00:00, 3229.80it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3937.24it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 407 selected samples
# step 20/407 | loss 1.3004 | lr 2.50e-05 | 3.78 it/s
# step 40/407 | loss 0.8694 | lr 5.00e-05 | 3.98 it/s
# step 60/407 | loss 0.5451 | lr 4.96e-05 | 4.03 it/s
# step 80/407 | loss 0.4399 | lr 4.85e-05 | 4.05 it/s
# step 100/407 | loss 0.4449 | lr 4.68e-05 | 4.07 it/s
# step 120/407 | loss 0.4490 | lr 4.44e-05 | 4.06 it/s
# step 140/407 | loss 0.4166 | lr 4.14e-05 | 4.06 it/s
# step 160/407 | loss 0.3914 | lr 3.79e-05 | 4.08 it/s
# step 180/407 | loss 0.5225 | lr 3.41e-05 | 4.08 it/s
# step 200/407 | loss 0.4256 | lr 3.00e-05 | 4.08 it/s
# step 220/407 | loss 0.4351 | lr 2.57e-05 | 4.09 it/s
# step 240/407 | loss 0.4567 | lr 2.15e-05 | 4.10 it/s
# step 260/407 | loss 0.4193 | lr 1.73e-05 | 4.10 it/s
# step 280/407 | loss 0.3901 | lr 1.34e-05 | 4.10 it/s
# step 300/407 | loss 0.3674 | lr 9.77e-06 | 4.10 it/s
# step 320/407 | loss 0.4032 | lr 6.62e-06 | 4.11 it/s
# step 340/407 | loss 0.4611 | lr 4.00e-06 | 4.11 it/s
# step 360/407 | loss 0.4430 | lr 2.00e-06 | 4.12 it/s
# step 380/407 | loss 0.3693 | lr 6.65e-07 | 4.11 it/s
# step 400/407 | loss 0.4438 | lr 4.49e-08 | 4.11 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_kmeans/slice0/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 11803.86it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# ...
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 15643.90it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_seed/slice1/adapter/merged
# rc=0 0.9 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/geography_mmlu.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_seed/slice2/selection.json --max-samples 225 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_seed/slice2/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 2
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  77%|███████▋  | 364/473 [00:00<00:00, 3633.75it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4082.14it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 225 selected samples
# step 20/225 | loss 0.3418 | lr 4.55e-05 | 4.08 it/s
# step 40/225 | loss 0.3843 | lr 4.90e-05 | 4.30 it/s
# step 60/225 | loss 0.2510 | lr 4.58e-05 | 4.37 it/s
# step 80/225 | loss 0.4375 | lr 4.06e-05 | 4.41 it/s
# step 100/225 | loss 0.2673 | lr 3.39e-05 | 4.43 it/s
# step 120/225 | loss 0.3093 | lr 2.64e-05 | 4.45 it/s
# step 140/225 | loss 0.3080 | lr 1.87e-05 | 4.46 it/s
# step 160/225 | loss 0.3866 | lr 1.16e-05 | 4.45 it/s
# step 180/225 | loss 0.2954 | lr 5.82e-06 | 4.47 it/s
# step 200/225 | loss 0.4137 | lr 1.85e-06 | 4.48 it/s
# step 220/225 | loss 0.3967 | lr 7.48e-08 | 4.48 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_seed/slice2/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 35017.38it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_seed/slice2/adapter/merged
# rc=0 1.0 min
# geography soup_seed adapters ready
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/geography_mmlu.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/slice0/selection.json --max-samples 225 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/slice0/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  79%|███████▊  | 372/473 [00:00<00:00, 3705.55it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4100.94it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 50 selected samples
# step 20/50 | loss 0.3397 | lr 3.75e-05 | 4.12 it/s
# step 40/50 | loss 0.2969 | lr 5.85e-06 | 4.35 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/slice0/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 40243.86it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/slice0/adapter/merged
# rc=0 0.4 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/geography_mmlu.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/slice1/selection.json --max-samples 225 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/slice1/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 1
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  53%|█████▎    | 252/473 [00:00<00:00, 2515.66it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3435.16it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 74 selected samples
# step 20/74 | loss 0.4095 | lr 4.55e-05 | 4.08 it/s
# step 40/74 | loss 0.4716 | lr 2.56e-05 | 4.29 it/s
# step 60/74 | loss 0.3935 | lr 5.20e-06 | 4.36 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/slice1/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 91180.52it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/slice1/adapter/merged
# rc=0 0.4 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/geography_mmlu.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/slice2/selection.json --max-samples 225 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/slice2/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 2
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  62%|██████▏   | 293/473 [00:00<00:00, 2922.73it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3714.11it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 101 selected samples
# step 20/101 | loss 0.2317 | lr 4.85e-05 | 4.11 it/s
# step 40/101 | loss 0.3758 | lr 3.77e-05 | 4.32 it/s
# step 60/101 | loss 0.5230 | lr 2.11e-05 | 4.40 it/s
# step 80/101 | loss 0.4187 | lr 6.29e-06 | 4.44 it/s
# step 100/101 | loss 0.3283 | lr 1.49e-08 | 4.47 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/slice2/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 47127.01it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/slice2/adapter/merged
# rc=0 0.5 min
# geography soup_kmeans adapters ready
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/geography_mmlu.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/slice0/selection.json --max-samples 225 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/slice0/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  53%|█████▎    | 252/473 [00:00<00:00, 2516.38it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3424.19it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 75 selected samples
# step 20/75 | loss 0.3753 | lr 4.56e-05 | 4.09 it/s
# step 40/75 | loss 0.2418 | lr 2.62e-05 | 4.28 it/s
# step 60/75 | loss 0.4279 | lr 5.77e-06 | 4.37 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/slice0/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 23187.18it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/slice0/adapter/merged
# rc=0 0.4 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/geography_mmlu.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/slice1/selection.json --max-samples 225 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/slice1/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 1
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  74%|███████▍  | 351/473 [00:00<00:00, 3503.59it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4055.43it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 75 selected samples
# step 20/75 | loss 0.4435 | lr 4.56e-05 | 4.10 it/s
# step 40/75 | loss 0.5136 | lr 2.62e-05 | 4.31 it/s
# step 60/75 | loss 0.3866 | lr 5.77e-06 | 4.39 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/slice1/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 13965.50it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/slice1/adapter/merged
# rc=0 0.4 min
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_train_ttl_anchored.py --model Qwen/Qwen3.5-0.8B --data data/AdaptEval/geography_mmlu.json --selection-file /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/slice2/selection.json --max-samples 225 --output-dir /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/slice2/adapter --lora-rank 8 --lora-alpha 16 --lora-keys q_proj,v_proj --epochs 1.0 --learning-rate 5e-05 --anchor-lambda 0.0 --seed 2
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  55%|█████▍    | 258/473 [00:00<00:00, 2568.14it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3559.94it/s]
# trainable params: 319,488 || all params: 853,305,408 || trainable%: 0.0374
# training on 75 selected samples
# step 20/75 | loss 0.3149 | lr 4.56e-05 | 4.08 it/s
# step 40/75 | loss 0.2197 | lr 2.62e-05 | 4.30 it/s
# step 60/75 | loss 0.2567 | lr 5.77e-06 | 4.38 it/s
# adapter -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/slice2/adapter
#
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 38597.89it/s]
#   copied preprocessor_config.json from source checkpoint
#   copied vocab.json from source checkpoint
#   copied merges.txt from source checkpoint
#   copied video_preprocessor_config.json from source checkpoint
# merged model -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/slice2/adapter/merged
# rc=0 0.4 min
# geography soup_random adapters ready

# %% [markdown]
# ## 3) Soup: linear weight-average the K adapters -> merged model (per arm)

# %%
from safetensors.torch import load_file, save_file
import torch, gc
from peft import PeftModel

def load_adapter_state(ad):
    f = ad/"adapter_model.safetensors"
    return load_file(str(f)) if f.exists() else torch.load(str(ad/"adapter_model.bin"), map_location="cpu")

def soup(ds, arm):
    out_merged = ROOT/ds/arm/"merged"
    if (out_merged/"config.json").exists(): return out_merged
    dirs = [ROOT/ds/arm/f"slice{j}"/"adapter" for j in range(K)]
    states = [load_adapter_state(d) for d in dirs]
    keys = list(states[0].keys())
    avg = {k: sum(s[k].float() for s in states)/len(states) for k in keys}      # linear soup of LoRA tensors
    tmp = ROOT/ds/arm/"soup_adapter"; tmp.mkdir(parents=True, exist_ok=True)
    shutil.copy(dirs[0]/"adapter_config.json", tmp/"adapter_config.json")
    save_file({k: v.to(torch.bfloat16).contiguous() for k, v in avg.items()}, str(tmp/"adapter_model.safetensors"))
    m, tok = load_base()
    merged = PeftModel.from_pretrained(m, str(tmp)).merge_and_unload()
    merged.save_pretrained(str(out_merged)); tok.save_pretrained(str(out_merged))
    del m, merged; gc.collect(); torch.cuda.empty_cache()
    return out_merged

for ds in DATASETS:
    for arm in SOUP_ARMS:
        mg = soup(ds, arm)
        ap = ROOT/ds/arm/"preds_adapted.jsonl"
        if ap.exists(): print("skip gen", ds, arm); continue
        sh([sys.executable, str(SCRIPTS/"ab_generate.py"), "--model", str(mg), "--data", DATA_FILES[ds],
            "--max-samples", str(N_BY_DATASET[ds]), "--output", str(ap), "--max-new-tokens", str(MAXNEW)],
           LOG/f"{ds}_{arm}_gen.log")
# Out:
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/merged --data data/AdaptEval/logiqa_random_5k.json --max-samples 1000 --output /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  76%|███████▌  | 360/473 [00:00<00:00, 3594.78it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4126.10it/s]
# generated 200/1000
# generated 400/1000
# generated 600/1000
# generated 800/1000
# generated 1000/1000
# 1000 prompts in 10.9s
# -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_seed/preds_adapted.jsonl
# rc=0 0.3 min
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/merged --data data/AdaptEval/logiqa_random_5k.json --max-samples 1000 --output /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  91%|█████████ | 429/473 [00:00<00:00, 4288.52it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4450.69it/s]
# generated 200/1000
# generated 400/1000
# generated 600/1000
# generated 800/1000
# generated 1000/1000
# 1000 prompts in 11.0s
# -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_kmeans/preds_adapted.jsonl
# rc=0 0.3 min
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/merged --data data/AdaptEval/logiqa_random_5k.json --max-samples 1000 --output /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  56%|█████▌    | 266/473 [00:00<00:00, 2657.32it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3642.55it/s]
# generated 200/1000
# generated 400/1000
# generated 600/1000
# generated 800/1000
# generated 1000/1000
# 1000 prompts in 10.9s
# -> /content/v2_dynamic_ce/saves_beat_tlm/logiqa/soup_random/preds_adapted.jsonl
# rc=0 0.3 min
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/merged --data data/AdaptEval/medicine_mcqa_random_5k.json --max-samples 1000 --output /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4790.94it/s]
# generated 200/1000
# generated 400/1000
# generated 600/1000
# generated 800/1000
# generated 1000/1000
# 1000 prompts in 22.1s
# -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_seed/preds_adapted.jsonl
# rc=0 0.5 min
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_kmeans/merged --data data/AdaptEval/medicine_mcqa_random_5k.json --max-samples 1000 --output /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_kmeans/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  69%|██████▉   | 328/473 [00:00<00:00, 3272.93it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4041.18it/s]
# generated 200/1000
# generated 400/1000
# generated 600/1000
# generated 800/1000
# generated 1000/1000
# 1000 prompts in 25.6s
# -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_kmeans/preds_adapted.jsonl
# rc=0 0.5 min
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_random/merged --data data/AdaptEval/medicine_mcqa_random_5k.json --max-samples 1000 --output /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_random/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  78%|███████▊  | 368/473 [00:00<00:00, 3678.21it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4128.23it/s]
# generated 200/1000
# generated 400/1000
# generated 600/1000
# generated 800/1000
# generated 1000/1000
# 1000 prompts in 26.0s
# -> /content/v2_dynamic_ce/saves_beat_tlm/medicine/soup_random/preds_adapted.jsonl
# rc=0 0.5 min
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_seed/merged --data data/AdaptEval/geography_mmlu.json --max-samples 225 --output /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_seed/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  61%|██████▏   | 290/473 [00:00<00:00, 2898.67it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3724.21it/s]
# generated 200/225
# generated 225/225
# 225 prompts in 2.4s
# -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_seed/preds_adapted.jsonl
# rc=0 0.1 min
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/merged --data data/AdaptEval/geography_mmlu.json --max-samples 225 --output /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  74%|███████▎  | 348/473 [00:00<00:00, 3468.01it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 4056.79it/s]
# generated 200/225
# generated 225/225
# 225 prompts in 2.4s
# -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_kmeans/preds_adapted.jsonl
# rc=0 0.1 min
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# RUN: /usr/bin/python3 /content/v2_dynamic_ce/rishabh-tlm/cuda_ttl/ab_routing/ab_generate.py --model /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/merged --data data/AdaptEval/geography_mmlu.json --max-samples 225 --output /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/preds_adapted.jsonl --max-new-tokens 12
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# loading with Qwen3_5ForConditionalGeneration
#
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Loading weights:  63%|██████▎   | 297/473 [00:00<00:00, 2965.97it/s]
# Loading weights: 100%|██████████| 473/473 [00:00<00:00, 3754.89it/s]
# generated 200/225
# generated 225/225
# 225 prompts in 2.4s
# -> /content/v2_dynamic_ce/saves_beat_tlm/geography/soup_random/preds_adapted.jsonl
# rc=0 0.1 min

# %% [markdown]
# ## 4) Result: does any soup beat BOTH tlm and fulldata on all 3?

# %%
import pandas as pd
def acc(path, at, gold):
    ok = []
    for ln in open(path):
        r = json.loads(ln); i = int(r["idx"])
        if i in gold: ok.append(bool(grading.is_correct(grading.extract(str(r.get("predict","")), at).value, gold[i], at)))
    return float(np.mean(ok)) if ok else float("nan")

REF = ["tlm", "fulldata"]
rows = []
for ds in DATASETS:
    at = grading.detect_answer_type(ds)
    recs = json.load(open(DATA_FILES[ds]))[: N_BY_DATASET[ds]]
    gold = {i: grading.extract(str(recs[i].get("output", "")), at).value
            for i in range(len(recs)) if recs[i].get("output")}
    row = {"dataset": ds, "base": round(acc(ROOT/ds/"preds_base.jsonl", at, gold), 3)}
    for arm in REF + list(SOUP_ARMS):
        p = ROOT/ds/arm/"preds_adapted.jsonl"
        row[arm] = round(acc(p, at, gold), 3) if p.exists() else None
    rows.append(row)
df = pd.DataFrame(rows); pd.set_option("display.width", 240); print(df.to_string(index=False))

print("\n=== soup vs BOTH baselines (must beat tlm AND fulldata on all 3) ===")
for arm in SOUP_ARMS:
    if df[arm].isna().any(): continue
    beats = all((df[arm] > df["tlm"]).tolist()) and all((df[arm] > df["fulldata"]).tolist())
    per = [f"{ds}:{(df.loc[df.dataset==ds,arm].iloc[0]-df.loc[df.dataset==ds,'fulldata'].iloc[0]):+.3f}" for ds in DATASETS]
    print(f"{arm:12s} vs fulldata: " + " ".join(per) + ("   <-- BEATS BOTH 3/3" if beats else ""))
print("\nsoup_seed>fulldata => souping regularization helps TTL. soup_kmeans>soup_seed => diversity adds")
print("more (your diversity_gain cashing in). If soups <= fulldata, adapters were too correlated to gain.")
# Out:
#   dataset  base   tlm  fulldata  soup_seed  soup_kmeans  soup_random
#    logiqa 0.391 0.409     0.452      0.423        0.406        0.401
#  medicine 0.382 0.417     0.434      0.412        0.398        0.399
# geography 0.556 0.560     0.636      0.600        0.573        0.582
#
# === soup vs BOTH baselines (must beat tlm AND fulldata on all 3) ===
# soup_seed    vs fulldata: logiqa:-0.029 medicine:-0.022 geography:-0.036
# soup_kmeans  vs fulldata: logiqa:-0.046 medicine:-0.036 geography:-0.063
# soup_random  vs fulldata: logiqa:-0.051 medicine:-0.035 geography:-0.054
#
# soup_seed>fulldata => souping regularization helps TTL. soup_kmeans>soup_seed => diversity adds
# more (your diversity_gain cashing in). If soups <= fulldata, adapters were too correlated to gain.
